# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen, Request
import lxml
import requests
import re
import pandas as pd
import numpy as np
import csv
from lxml import html
import requests
from langdetect import detect
import math
import os

# %%
def getURL(page):
    """
    :param page: html of web page (here: Python home page) 
    :return: urls in that page 
    """
    start_link = page.find("a href")
    if start_link == -1:
        return None, 0
    start_quote = page.find('"', start_link)
    end_quote = page.find('"', start_quote + 1)
    url = page[start_quote + 1: end_quote]
    return url, end_quote

def PageScraper(url):
    l=[]
    response = requests.get(url)
    page = str(BeautifulSoup(response.content))
    while url!= '#comment_form':
        url, n = getURL(page)
        page = page[n:]
        if url and url[:5]=='/book':
            l.append(url)
    return l

#Scraps the first 100 pages
outfile = open("Pages101-200.txt", "a")
for k in range(101,201):
    url = 'https://www.goodreads.com/list/show/1.Best_Books_Ever?page='+str(k)
    L = PageScraper(url)
    for k in range(len(L)):
        outfile.write('https://www.goodreads.com/'+L[k])
        outfile.write("\n")
outfile.close()

# %%
#Creating folders fo each page
path = "C:\\Users\\Eloisa\\Desktop\\UNI LORENZO\\ADM\\Homework 3"
os.chdir(path)
for i in range(101):
    if 0<i<10:
        os.makedirs("page_10"+str(i))
    if 9<i<100:
        os.makedirs("page_1"+str(i))
    if i==100:
        os.makedirs("page_200")

# %%
# First, I make sure i am in the directory that has the text file with the URLS
path = "C:\\Users\\Eloisa\\Desktop\\UNI LORENZO\\ADM\\Homework 3"
os.chdir(path)

i = 9901
page = 100

with open("Pages101-200.txt", "r") as urls:
    # I previously created the 100 directories, from page 101 to page 200
    # I change the working directory for which i want the HTMLs 
    path = "C:\\Users\\Eloisa\\Desktop\\UNI LORENZO\\ADM\\Homework 3\\page_200"
    os.chdir(path)

    for url in urls.readlines():

        html = urlopen(url)

        soup = BeautifulSoup(html.read(), 'html.parser')
        
        # The logic here is not the best but it works- 
        # Basically, once every 100 urls treated I change the directory
        
        if i <= page*100:
                # We stay in the current directory
            with open("article_"+str(i)+".html", "w", encoding="utf-8") as outfile:
                outfile.write(str(soup))

            i = i + 1

        if i == (page*100)+1 and 0<page<9:
            page = page + 1
            path = "C:\\Users\\Eloisa\\Desktop\\UNI LORENZO\\ADM\\Homework 3\\page_10"+str(page)
            os.chdir(path)

            with open("article_"+str(i)+".html", "w", encoding="utf-8") as outfile:
                outfile.write(str(soup))
            
            
        if i == (page*100)+1 and 8<page<99:
            page = page + 1
            path = "C:\\Users\\Eloisa\\Desktop\\UNI LORENZO\\ADM\\Homework 3\\page_1"+str(page)
            os.chdir(path)

            with open("article_"+str(i)+".html", "w", encoding="utf-8") as outfile:
                outfile.write(str(soup))
            
            
        if i == (page*100)+1 and page==99:
            page = page + 1
            path = "C:\\Users\\Eloisa\\Desktop\\UNI LORENZO\\ADM\\Homework 3\\page_"+str(page*2)
            os.chdir(path)
    
            with open("article_"+str(i)+".html", "w", encoding="utf-8") as outfile:
                outfile.write(str(soup))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-05f022e2579d> in <module>
#      14     for url in urls.readlines():
#      15
# ---> 16         html = urlopen(url)
#      17
#      18         soup = BeautifulSoup(html.read(), 'html.parser')
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     508         # accept a URL or a Request object
#     509         if isinstance(fullurl, str):
# --> 510             req = Request(fullurl, data)
#     511         else:
#     512             req = fullurl
#
# ~\Anaconda3\lib\urllib\request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     326                  origin_req_host=None, unverifiable=False,
#     327                  method=None):
# --> 328         self.full_url = url
#     329         self.headers = {}
#     330         self.unredirected_hdrs = {}
#
# ~\Anaconda3\lib\urllib\request.py in full_url(self, url)
#     352         self._full_url = unwrap(url)
#     353         self._full_url, self.fragment = splittag(self._full_url)
# --> 354         self._parse()
#     355
#     356     @full_url.deleter
#
# ~\Anaconda3\lib\urllib\request.py in _parse(self)
#     381         self.type, rest = splittype(self._full_url)
#     382         if self.type is None:
# --> 383             raise ValueError("unknown url type: %r" % self.full_url)
#     384         self.host, self.selector = splithost(rest)
#     385         if self.host:
#
# ValueError: unknown url type: ''

# %%
# SECTION 1

# All functions to retrieve the informations

def get_title(soup):
    try:
        title = soup.find(id="bookTitle").contents[0].strip()
        return title
    except AttributeError:
        return ""

def get_series(soup):
    try:
        serie = soup.find(id="bookSeries").get_text().strip().replace("(","").replace(")","")
        #regex = "#.*"
        #serie = re.sub(regex, "",serie)
        return serie
    except AttributeError:
        return ""

def get_author(soup):
    try:
        author = soup.find_all(class_="authorName__container")
        author_list = " ".join([x.get_text().strip() for x in author])
        return author_list
    except AttributeError:
        return ""

def get_pages(soup):
    try:
        pages = soup.find(itemprop ="numberOfPages").get_text().split()[0]
        return int(pages)
    except AttributeError:
        return ""

def get_ratingValue(soup):
    try:
        ratingValue = soup.find(itemprop ="ratingValue").get_text().split()[0]
        return float(ratingValue)
    except AttributeError:
        return ""

def get_ratingCount(soup):
    try:
        test = []
        ratingCount = soup.find_all(class_ ="gr-hyperlink", href="#other_reviews")
        for x in ratingCount:
            test.append(x.get_text().split())
        return int(test[0][0].replace(",",""))
    except AttributeError:
        return ""

def get_reviewCount(soup):
    try:
        test = []
        ratingCount = soup.find_all(class_ ="gr-hyperlink", href="#other_reviews")
        for x in ratingCount:
            test.append(x.get_text().split())
        return int(test[1][0].replace(",",""))
    except AttributeError:
        return ""

def get_date(soup):
    try:
        regex = "by.*"
        date = soup.find_all(class_ = "row")
        date = re.sub(regex,"" ,str(date[1].contents[0]).replace("Published","")).strip()
        return date
    except AttributeError:
        return ""

def get_setting(soup):
    try:
        string = re.compile("/places/.")
        test = soup.find_all(href=string)

        places_list = " ".join([(str(a.contents[0])) for a in test])

        return places_list
    except AttributeError:
        return ""

def get_plot(soup):
    try:
        plot = soup.find(id="description")
        plot = plot.find_all(id= re.compile("freeText\.*"))

        final_plot = [] # It seems i need a list because joining on an empty string gives me a !"£$%&"@ blank

    # now there should not be a case where there are 3 span tags ...hopefully
        if len(plot) > 1:
            final_plot.append(plot[1].get_text())
        else:
            final_plot.append(plot[0].get_text())

        return final_plot[0]
    except AttributeError:
        return ""


def get_char(soup):
    try:
        string = re.compile("/characters/.")
        test = soup.find_all(href=string)

        char_list= " ".join([(str(a.contents[0])) for a in test])

        return char_list
    except AttributeError:
        return ""

def get_url(soup):
    try:
        regex = "https://www.goodreads.com/book/show/."
        ratingCount = soup.find(href =re.compile(regex), rel="canonical")
        return ratingCount.get('href')
    except AttributeError:
        return ""

# %%
# SECTION 2


eng_count = 1
nb_html_articles = 100
page = 101


for k in range(3):

    path = "C:\\Users\\Eloisa\\Desktop\\UNI LORENZO\\ADM\\Homework 3\\page_"+str(page)
    os.chdir(path)
    
    
    for i in range(1,nb_html_articles+1):

        path = "C:\\Users\\Eloisa\\Desktop\\UNI LORENZO\\ADM\\Homework 3\\page_"+str(page)
        os.chdir(path)
    
        html = open("article_"+str(k*100+i)+".html", "r", encoding="utf-8")
        soup = BeautifulSoup(html.read(), 'html.parser')
        try:
            if detect(get_plot(soup)) == "en":
                eng_count += 1
                
                path = "C:\\Users\\Eloisa\\Desktop\\UNI LORENZO\\ADM\\Homework 3\\Test"
                os.chdir(path)
                with open("article_"+str(eng_count)+".tsv", 'w', encoding="utf-8") as f_output:
                    test_list_tsv = [get_title(soup), 
                    get_series(soup), 
                    get_author(soup),
                    get_ratingValue(soup),
                    get_ratingCount(soup), 
                    get_reviewCount(soup),
                    get_plot(soup),
                    get_pages(soup),
                    get_date(soup),
                    get_setting(soup),
                    get_char(soup),
                    get_url(soup)]
            
                    header_list = ["bookTitle","bookSeries","bookAuthors","ratingValue","ratingCount","reviewCount","Plot","NumberofPages","Date","Characters","Setting","URL"]

                    path = "C:\\Users\\Eloisa\\Desktop\\UNI LORENZO\\ADM\\Homework 3"
                    os.chdir(path)

                    tsv_output = csv.writer(f_output, delimiter='\t')
                    tsv_output.writerow(header_list)
                    tsv_output.writerow(test_list_tsv)
                    
        except:
            language ="error"
        #ErrorCode.CantDetectError
    page = page + 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-107-27849878429e> in <module>
#      18         os.chdir(path)
#      19
# ---> 20         html = open("article_"+str(k*100+i)+".html", "r", encoding="utf-8")
#      21         soup = BeautifulSoup(html.read(), 'html.parser')
#      22         try:
#
# ~\Anaconda3\lib\codecs.py in __init__(self, errors)
#     307     byte sequences.
#     308     """
# --> 309     def __init__(self, errors='strict'):
#     310         IncrementalDecoder.__init__(self, errors)
#     311         # undecoded input that is kept between calls to decode()
#
# KeyboardInterrupt:

# %%
path = "C:\\Users\\Eloisa\\Desktop\\UNI LORENZO\\ADM\\Homework 3\\Data(no 0)"
os.chdir(path)
t = []
s = []
p = []
y = []
for x in range(1,26886):
    try:
        data = pd.read_csv("article_"+str(x)+".tsv", sep = "\t", encoding = "utf-8")
        title = data['bookTitle'].item()
        series = data['bookSeries'].item()
        pages = data['NumberofPages'].item()
        date = data['Date'].item()
        year = str(date)[-4:]
        t.append(title)
        s.append(series)
        p.append(pages)
        y.append(int(year))
    except FileNotFoundError :
        pass
# Out:
# C:\Users\Eloisa\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: `item` has been deprecated and will be removed in a future version
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Eloisa\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: `item` has been deprecated and will be removed in a future version
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Eloisa\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: `item` has been deprecated and will be removed in a future version
#   if sys.path[0] == '':
# C:\Users\Eloisa\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: `item` has been deprecated and will be removed in a future version
#   del sys.path[0]

# %%
yl = []

for i in range(len(y)):
    try:
        yl.append(int(y[i]))
    except:
        print('wrong value', y[i])
        
yl
# Out:
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value h 17
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# wrong value nan
# [2008,
#  2004,
#  2006,
#  2000,
#  2006,
#  2006,
#  1996,
#  2002,
#  2012,
#  2012,
#  1999,
#  2007,
#  1964,
#  2002,
#  2006,
#  2004,
#  2005,
#  2000,
#  2003,
#  1987,
#  2011,
#  2012,
#  1999,
#  2004,
#  2014,
#  1999,
#  2002,
#  2004,
#  2007,
#  2004,
#  2009,
#  2003,
#  2003,
#  2000,
#  2001,
#  2002,
#  2013,
#  1986,
#  1998,
#  2003,
#  2001,
#  2003,
#  2006,
#  1998,
#  2007,
#  2005,
#  2017,
#  2002,
#  1997,
#  2006,
#  2000,
#  1988,
#  2006,
#  2006,
#  2003,
#  2007,
#  1995,
#  1999,
#  2004,
#  2018,
#  1998,
#  2006,
#  2004,
#  2019,
#  2002,
#  1990,
#  1998,
#  1975,
#  1998,
#  2004,
#  2007,
#  2006,
#  1963,
#  2012,
#  1998,
#  2005,
#  2005,
#  2008,
#  2013,
#  2013,
#  2019,
#  2006,
#  2019,
#  2006,
#  2002,
#  2005,
#  2007,
#  1981,
#  2005,
#  1996,
#  2003,
#  2004,
#  1973,
#  1999,
#  1996,
#  2000,
#  2001,
#  1984,
#  2004,
#  1990,
#  2003,
#  1997,
#  2002,
#  2003,
#  2010,
#  2006,
#  2004,
#  2003,
#  1989,
#  1996,
#  2007,
#  1980,
#  2006,
#  2005,
#  2005,
#  1976,
#  1972,
#  2006,
#  2005,
#  2004,
#  1994,
#  2000,
#  2009,
#  1994,
#  1999,
#  2000,
#  2002,
#  2003,
#  1994,
#  2003,
#  2018,
#  2009,
#  2003,
#  1985,
#  2011,
#  1987,
#  1999,
#  2000,
#  2005,
#  2009,
#  2005,
#  1987,
#  2003,
#  1995,
#  2003,
#  1987,
#  2002,
#  1994,
#  2003,
#  2008,
#  2012,
#  2002,
#  2000,
#  2004,
#  2002,
#  2007,
#  2003,
#  2005,
#  2006,
#  2001,
#  1995,
#  2008,
#  2007,
#  2006,
#  1998,
#  2003,
#  2009,
#  2003,
#  2003,
#  2009,
#  2013,
#  2008,
#  2016,
#  2010,
#  2001,
#  2007,
#  2006,
#  2006,
#  2004,
#  2001,
#  2006,
#  2004,
#  1996,
#  2009,
#  2010,
#  1990,
#  2009,
#  2009,
#  2003,
#  1997,
#  1990,
#  2001,
#  2011,
#  2016,
#  2003,
#  2003,
#  1999,
#  2004,
#  2004,
#  2009,
#  2000,
#  2009,
#  2007,
#  2006,
#  2003,
#  2002,
#  1994,
#  2003,
#  2006,
#  2011,
#  2012,
#  2009,
#  2010,
#  2004,
#  2007,
#  2004,
#  2012,
#  2001,
#  1994,
#  1957,
#  1987,
#  2009,
#  2012,
#  2010,
#  2011,
#  2010,
#  1999,
#  2003,
#  1999,
#  1997,
#  2005,
#  2005,
#  1984,
#  2002,
#  2006,
#  2002,
#  2011,
#  2009,
#  2005,
#  1998,
#  1998,
#  2005,
#  1987,
#  1997,
#  2012,
#  2002,
#  1996,
#  2013,
#  1990,
#  2008,
#  2007,
#  1998,
#  1995,
#  2018,
#  2005,
#  2005,
#  2001,
#  1977,
#  1988,
#  1991,
#  2008,
#  2004,
#  2010,
#  1993,
#  2001,
#  2012,
#  2011,
#  2009,
#  2009,
#  2004,
#  2019,
#  2004,
#  2003,
#  2004,
#  1987,
#  1999,
#  2003,
#  1997,
#  2005,
#  2004,
#  1999,
#  2005,
#  1986,
#  2014,
#  1991,
#  2008,
#  2002,
#  1995,
#  2003,
#  1998,
#  2008,
#  1998,
#  2004,
#  1990,
#  2006,
#  2000,
#  2002,
#  2000,
#  1995,
#  2006,
#  2002,
#  2001,
#  2012,
#  1995,
#  2004,
#  2011,
#  2013,
#  2006,
#  1992,
#  2002,
#  2010,
#  2011,
#  2002,
#  2001,
#  2011,
#  2011,
#  2016,
#  2004,
#  2004,
#  2010,
#  2002,
#  1994,
#  1999,
#  2001,
#  1996,
#  2005,
#  2004,
#  2006,
#  2003,
#  1998,
#  2005,
#  2013,
#  2008,
#  2012,
#  2010,
#  2004,
#  2013,
#  2011,
#  2013,
#  2008,
#  2003,
#  2009,
#  2003,
#  2003,
#  2001,
#  2005,
#  2008,
#  1991,
#  2005,
#  1995,
#  1997,
#  650,
#  1996,
#  2012,
#  2006,
#  2012,
#  2001,
#  2006,
#  2001,
#  2009,
#  1985,
#  1999,
#  2005,
#  2006,
#  2007,
#  1990,
#  2004,
#  1991,
#  2003,
#  2003,
#  2003,
#  2001,
#  2008,
#  1995,
#  2002,
#  1989,
#  2012,
#  2006,
#  2002,
#  1995,
#  1984,
#  1991,
#  2014,
#  2010,
#  2006,
#  2004,
#  2006,
#  2009,
#  2011,
#  2000,
#  2000,
#  2003,
#  2001,
#  1997,
#  2001,
#  2003,
#  2015,
#  1993,
#  1993,
#  2010,
#  2001,
#  2001,
#  1999,
#  2004,
#  2007,
#  2011,
#  2001,
#  2003,
#  2014,
#  2009,
#  2018,
#  1994,
#  2011,
#  1991,
#  2005,
#  1999,
#  1952,
#  2003,
#  2005,
#  2005,
#  2005,
#  2010,
#  1988,
#  2011,
#  2006,
#  2011,
#  2010,
#  1979,
#  2002,
#  2012,
#  2010,
#  2005,
#  2006,
#  1987,
#  2014,
#  1996,
#  1992,
#  2011,
#  2003,
#  2005,
#  2008,
#  2002,
#  1997,
#  2007,
#  2013,
#  2004,
#  2003,
#  2007,
#  2004,
#  2009,
#  2008,
#  2014,
#  2007,
#  2011,
#  2005,
#  2000,
#  2015,
#  2006,
#  2001,
#  2006,
#  1998,
#  2004,
#  2000,
#  2003,
#  2013,
#  2008,
#  2011,
#  1993,
#  1989,
#  2004,
#  2003,
#  2002,
#  2014,
#  2007,
#  2005,
#  1989,
#  1995,
#  2014,
#  2001,
#  2001,
#  2008,
#  2005,
#  2006,
#  2003,
#  2005,
#  1994,
#  2017,
#  2006,
#  2010,
#  2012,
#  2013,
#  2004,
#  2010,
#  1994,
#  2011,
#  2003,
#  2010,
#  2003,
#  1976,
#  1982,
#  2006,
#  2007,
#  2014,
#  2017,
#  2003,
#  2003,
#  2014,
#  2004,
#  2006,
#  2002,
#  2008,
#  2009,
#  2003,
#  2006,
#  2000,
#  2000,
#  2015,
#  2003,
#  2007,
#  2007,
#  2008,
#  2009,
#  2006,
#  2007,
#  2004,
#  2011,
#  1994,
#  2000,
#  1962,
#  2004,
#  2002,
#  2007,
#  2004,
#  2000,
#  2013,
#  2008,
#  1983,
#  1974,
#  2011,
#  2015,
#  2009,
#  2011,
#  2001,
#  2004,
#  1999,
#  2010,
#  2005,
#  1995,
#  2003,
#  2012,
#  2004,
#  2009,
#  1996,
#  2009,
#  1998,
#  2016,
#  1994,
#  1962,
#  2005,
#  2008,
#  2012,
#  2014,
#  2015,
#  2004,
#  1999,
#  2002,
#  2018,
#  1999,
#  2007,
#  2018,
#  2005,
#  2007,
#  2012,
#  2009,
#  2007,
#  2016,
#  2008,
#  1992,
#  1999,
#  1990,
#  1989,
#  2006,
#  2014,
#  1994,
#  2003,
#  2013,
#  2010,
#  2004,
#  2000,
#  1996,
#  2006,
#  2002,
#  1997,
#  2010,
#  2002,
#  2018,
#  2015,
#  2008,
#  2005,
#  2006,
#  1998,
#  2005,
#  2003,
#  2007,
#  1998,
#  1997,
#  2006,
#  2000,
#  2010,
#  2003,
#  2011,
#  2001,
#  2011,
#  2005,
#  2006,
#  2010,
#  2008,
#  2014,
#  2011,
#  2003,
#  2005,
#  2003,
#  1987,
#  2011,
#  2007,
#  2006,
#  2006,
#  2001,
#  2005,
#  1982,
#  2006,
#  1997,
#  2005,
#  2014,
#  1991,
#  2006,
#  2005,
#  2013,
#  1998,
#  2004,
#  2005,
#  1994,
#  2006,
#  2018,
#  2007,
#  2006,
#  2014,
#  2006,
#  2003,
#  2001,
#  2000,
#  2013,
#  2011,
#  1998,
#  1996,
#  1997,
#  2014,
#  2001,
#  2004,
#  2013,
#  2009,
#  2006,
#  2001,
#  2016,
#  2011,
#  2006,
#  2016,
#  1995,
#  2006,
#  2006,
#  2001,
#  2006,
#  2001,
#  2005,
#  2001,
#  1988,
#  2008,
#  1999,
#  1996,
#  2003,
#  2019,
#  2002,
#  1999,
#  2001,
#  2008,
#  2013,
#  1988,
#  2012,
#  2006,
#  2003,
#  2007,
#  2002,
#  2002,
#  2003,
#  2006,
#  2017,
#  2012,
#  2015,
#  2012,
#  2000,
#  2006,
#  2003,
#  2006,
#  2018,
#  2006,
#  2013,
#  1990,
#  2009,
#  2007,
#  2005,
#  2002,
#  1996,
#  1992,
#  2004,
#  2002,
#  1999,
#  1978,
#  2009,
#  2004,
#  2006,
#  2005,
#  2006,
#  1999,
#  1990,
#  2009,
#  2014,
#  1998,
#  2004,
#  2010,
#  2013,
#  2002,
#  1998,
#  2003,
#  2002,
#  2006,
#  2011,
#  2001,
#  2003,
#  2004,
#  2003,
#  2008,
#  2004,
#  2006,
#  2000,
#  2006,
#  2006,
#  1996,
#  2002,
#  2012,
#  2012,
#  1999,
#  2007,
#  1964,
#  2002,
#  2006,
#  2004,
#  2005,
#  2000,
#  2003,
#  1987,
#  2011,
#  2012,
#  1999,
#  2004,
#  2014,
#  1999,
#  2002,
#  2004,
#  2007,
#  2004,
#  2009,
#  2003,
#  2003,
#  2000,
#  2001,
#  2002,
#  2013,
#  1986,
#  1998,
#  2003,
#  2001,
#  2003,
#  2006,
#  1998,
#  2007,
#  2005,
#  2017,
#  2002,
#  1997,
#  2006,
#  2000,
#  1988,
#  2006,
#  2006,
#  2003,
#  2007,
#  1995,
#  1999,
#  2004,
#  2018,
#  1998,
#  2006,
#  2004,
#  2019,
#  2002,
#  1990,
#  1998,
#  1975,
#  1998,
#  2004,
#  2007,
#  2006,
#  1963,
#  2012,
#  1998,
#  2005,
#  2005,
#  2008,
#  2013,
#  2013,
#  2019,
#  2006,
#  2019,
#  2006,
#  2002,
#  2005,
#  2007,
#  1981,
#  2005,
#  1996,
#  2003,
#  2004,
#  1973,
#  1999,
#  1996,
#  2000,
#  2001,
#  1984,
#  2004,
#  1990,
#  2003,
#  1997,
#  2002,
#  2003,
#  2010,
#  2006,
#  2004,
#  2003,
#  1989,
#  1996,
#  2007,
#  1980,
#  2006,
#  2005,
#  2005,
#  1976,
#  1972,
#  2006,
#  2005,
#  2004,
#  1994,
#  2000,
#  2009,
#  1994,
#  1999,
#  2000,
#  2002,
#  2003,
#  1994,
#  2003,
#  2018,
#  2009,
#  2003,
#  1985,
#  2011,
#  1987,
#  1999,
#  2000,
#  2005,
#  2009,
#  2005,
#  1987,
#  2003,
#  1995,
#  2003,
#  1987,
#  2002,
#  1994,
#  2003,
#  2008,
#  2012,
#  2002,
#  2000,
#  2004,
#  2002,
#  2007,
#  2003,
#  2005,
#  2006,
#  2001,
#  1995,
#  2008,
#  2007,
#  2006,
#  1998,
#  2003,
#  2009,
#  2003,
#  2003,
#  2009,
#  2013,
#  2008,
#  2016,
#  2010,
#  2001,
#  2007,
#  2006,
#  2006,
#  2004,
#  2001,
#  2006,
#  2004,
#  1996,
#  2009,
#  2010,
#  1990,
#  2009,
#  2009,
#  2003,
#  1997,
#  1990,
#  2001,
#  2011,
#  2016,
#  2003,
#  2003,
#  1999,
#  2004,
#  2004,
#  2009,
#  2000,
#  2009,
#  2007,
#  2006,
#  2003,
#  2002,
#  1994,
#  2003,
#  2006,
#  2011,
#  2012,
#  2009,
#  2010,
#  2004,
#  2007,
#  2004,
#  2012,
#  2001,
#  1994,
#  1957,
#  1987,
#  2009,
#  2012,
#  2010,
#  2011,
#  2010,
#  1999,
#  2003,
#  1999,
#  1997,
#  2005,
#  2005,
#  1984,
#  2002,
#  2006,
#  2002,
#  2011,
#  2009,
#  2005,
#  1998,
#  1998,
#  2005,
#  1987,
#  1997,
#  2012,
#  2002,
#  1996,
#  2013,
#  1990,
#  2008,
#  2007,
#  1998,
#  1995,
#  2018,
#  2005,
#  2005,
#  2001,
#  1977,
#  1988,
#  1991,
#  ...]

# %%
cl = [x for x in s if str(x) != 'nan']

# %%
sl = cl[:10]

# %%
sl
# Out:
# ['The Hunger Games ',
#  'Harry Potter ',
#  'To Kill a Mockingbird',
#  'The Twilight Saga ',
#  'The Chronicles of Narnia Publication Order ',
#  'The Lord of the Rings ',
#  "The Hitchhiker's Guide to the Galaxy ",
#  'Robert Langdon ',
#  "Alice's Adventures in Wonderland ",
#  'Divergent ']

# %%
dictionary_pages = {}
dictionary_years = {}
for j in range(len(sl)):
    index = []
    pages = []
    years = []
    for i in range(len(s)):
        if sl[j] == s[i]:
            index.append(i)
    for elem in index:
        pages.append(p[elem])
        years.append(y[elem])
    dictionary_pages[sl[j]] = pages
    dictionary_years[sl[j]] = years

# %%
dictionary_pages
# Out:
# {'The Hunger Games ': [374,
#   1155,
#   391,
#   390,
#   374,
#   1155,
#   391,
#   390,
#   374,
#   1155,
#   391,
#   390,
#   374,
#   374,
#   374,
#   1155,
#   391,
#   374,
#   1155,
#   391,
#   390,
#   374,
#   1155,
#   391,
#   390,
#   374,
#   1155,
#   391,
#   390,
#   374,
#   1155,
#   391,
#   390],
#  'Harry Potter ': [870,
#   309,
#   759,
#   435,
#   734,
#   652,
#   341,
#   4100,
#   870,
#   309,
#   759,
#   435,
#   734,
#   652,
#   341,
#   4100,
#   870,
#   309,
#   759,
#   435,
#   734,
#   652,
#   341,
#   4100,
#   870,
#   870,
#   309,
#   759,
#   435,
#   870,
#   309,
#   759,
#   435,
#   734,
#   652,
#   341,
#   870,
#   309,
#   759,
#   435,
#   734,
#   652,
#   341,
#   4100,
#   343,
#   1500,
#   870,
#   309,
#   759,
#   435,
#   734,
#   652,
#   341,
#   4100,
#   870,
#   309,
#   759,
#   435,
#   734,
#   652,
#   341,
#   4100,
#   870,
#   309,
#   759,
#   435,
#   734,
#   652,
#   341,
#   4100,
#   343,
#   1500,
#   3342,
#   4],
#  'To Kill a Mockingbird': [324,
#   324,
#   324,
#   324,
#   324,
#   324,
#   324,
#   324,
#   324,
#   324,
#   309],
#  'The Twilight Saga ': [501,
#   1690,
#   501,
#   1690,
#   178,
#   629,
#   756,
#   563,
#   501,
#   1690,
#   501,
#   501,
#   501,
#   501,
#   1690,
#   178,
#   629,
#   756,
#   563,
#   501,
#   1690,
#   501,
#   1690,
#   178,
#   501,
#   1690,
#   178,
#   629,
#   756,
#   563,
#   738],
#  'The Chronicles of Narnia Publication Order ': [767,
#   206,
#   248,
#   288,
#   224,
#   243,
#   240,
#   767,
#   206,
#   248,
#   288,
#   224,
#   243,
#   240,
#   767,
#   206,
#   248,
#   288,
#   224,
#   243,
#   240,
#   767,
#   767,
#   767,
#   206,
#   767,
#   206,
#   248,
#   288,
#   224,
#   243,
#   240,
#   767,
#   206,
#   248,
#   288,
#   224,
#   243,
#   240,
#   767,
#   206,
#   248,
#   288,
#   224,
#   243,
#   240,
#   767,
#   206,
#   248,
#   288,
#   224,
#   243,
#   240],
#  'The Lord of the Rings ': [1728,
#   527,
#   398,
#   1216,
#   385,
#   322,
#   1728,
#   527,
#   398,
#   1216,
#   385,
#   322,
#   1728,
#   527,
#   398,
#   1216,
#   385,
#   322,
#   1728,
#   527,
#   1728,
#   527,
#   398,
#   1728,
#   527,
#   398,
#   1216,
#   322,
#   1728,
#   527,
#   398,
#   1216,
#   322,
#   1728,
#   527,
#   398,
#   1216,
#   322,
#   1728,
#   527,
#   398,
#   1216,
#   322],
#  "The Hitchhiker's Guide to the Galaxy ": [193,
#   815,
#   193,
#   815,
#   250,
#   224,
#   193,
#   815,
#   250,
#   193,
#   193,
#   815,
#   193,
#   815,
#   250,
#   224,
#   225,
#   193,
#   815,
#   250,
#   193,
#   815,
#   250,
#   224,
#   193,
#   815,
#   250,
#   224,
#   225,
#   288,
#   1003],
#  'Robert Langdon ': [489,
#   509,
#   736,
#   463,
#   489,
#   509,
#   736,
#   463,
#   489,
#   509,
#   736,
#   463,
#   489,
#   489,
#   489,
#   509,
#   736,
#   463,
#   489,
#   509,
#   736,
#   463,
#   489,
#   509,
#   736,
#   463,
#   489,
#   509,
#   736,
#   463,
#   456],
#  "Alice's Adventures in Wonderland ": [239,
#   239,
#   239,
#   239,
#   239,
#   239,
#   96,
#   239,
#   239,
#   239,
#   96],
#  'Divergent ': [487,
#   525,
#   526,
#   487,
#   525,
#   526,
#   487,
#   525,
#   526,
#   487,
#   487,
#   525,
#   487,
#   525,
#   526,
#   208,
#   43,
#   487,
#   525,
#   526,
#   487,
#   525,
#   526,
#   487,
#   525,
#   526,
#   208,
#   43,
#   55,
#   1616,
#   40]}

# %%
dictionary_years
# Out:
# {'The Hunger Games ': [2008,
#   '2010',
#   '2009',
#   '2010',
#   '2008',
#   '2010',
#   '2009',
#   '2010',
#   '2008',
#   '2010',
#   '2009',
#   '2010',
#   '2008',
#   '2008',
#   '2008',
#   '2010',
#   '2009',
#   '2008',
#   '2010',
#   '2009',
#   '2010',
#   '2008',
#   '2010',
#   '2009',
#   '2010',
#   '2008',
#   '2010',
#   '2009',
#   '2010',
#   '2008',
#   '2010',
#   '2009',
#   '2010'],
#  'Harry Potter ': [2004,
#   2003,
#   2007,
#   2004,
#   2002,
#   2006,
#   '1999',
#   '2007',
#   '2004',
#   '2003',
#   '2007',
#   '2004',
#   '2002',
#   '2006',
#   '1999',
#   '2007',
#   '2004',
#   '2003',
#   '2007',
#   '2004',
#   '2002',
#   '2006',
#   '1999',
#   '2007',
#   '2004',
#   '2004',
#   '2003',
#   '2007',
#   '2004',
#   '2004',
#   '2003',
#   '2007',
#   '2004',
#   '2002',
#   '2006',
#   '1999',
#   '2004',
#   '2003',
#   '2007',
#   '2004',
#   '2002',
#   '2006',
#   '1999',
#   '2007',
#   '2016',
#   '1999',
#   '2004',
#   '2003',
#   '2007',
#   '2004',
#   '2002',
#   '2006',
#   '1999',
#   '2007',
#   '2004',
#   '2003',
#   '2007',
#   '2004',
#   '2002',
#   '2006',
#   '1999',
#   '2007',
#   '2004',
#   '2003',
#   '2007',
#   '2004',
#   '2002',
#   '2006',
#   '1999',
#   '2007',
#   '2016',
#   '1999',
#   '2005',
#   '2008'],
#  'To Kill a Mockingbird': [2006,
#   '2006',
#   '2006',
#   '2006',
#   '2006',
#   '2006',
#   '2006',
#   '2006',
#   '2006',
#   '2006',
#   '2010'],
#  'The Twilight Saga ': [2006,
#   '2007',
#   '2006',
#   '2007',
#   '2010',
#   '2007',
#   '2008',
#   '2006',
#   '2006',
#   '2007',
#   '2006',
#   '2006',
#   '2006',
#   '2006',
#   '2007',
#   '2010',
#   '2007',
#   '2008',
#   '2006',
#   '2006',
#   '2007',
#   '2006',
#   '2007',
#   '2010',
#   '2006',
#   '2007',
#   '2010',
#   '2007',
#   '2008',
#   '2006',
#   '2015'],
#  'The Chronicles of Narnia Publication Order ': [2002,
#   '2005',
#   '2006',
#   '2005',
#   '1995',
#   '2008',
#   '2005',
#   '2002',
#   '2005',
#   '2006',
#   '2005',
#   '1995',
#   '2008',
#   '2005',
#   '2002',
#   '2005',
#   '2006',
#   '2005',
#   '1995',
#   '2008',
#   '2005',
#   '2002',
#   '2002',
#   '2002',
#   '2005',
#   '2002',
#   '2005',
#   '2006',
#   '2005',
#   '1995',
#   '2008',
#   '2005',
#   '2002',
#   '2005',
#   '2006',
#   '2005',
#   '1995',
#   '2008',
#   '2005',
#   '2002',
#   '2005',
#   '2006',
#   '2005',
#   '1995',
#   '2008',
#   '2005',
#   '2002',
#   '2005',
#   '2006',
#   '2005',
#   '1995',
#   '2008',
#   '2005'],
#  'The Lord of the Rings ': [2012,
#   1973,
#   '2003',
#   '2005',
#   '1974',
#   '2003',
#   '2012',
#   '1973',
#   '2003',
#   '2005',
#   '1974',
#   '2003',
#   '2012',
#   '1973',
#   '2003',
#   '2005',
#   '1974',
#   '2003',
#   '2012',
#   '1973',
#   '2012',
#   '1973',
#   '2003',
#   '2012',
#   '1973',
#   '2003',
#   '2005',
#   '2003',
#   '2012',
#   '1973',
#   '2003',
#   '2005',
#   '2003',
#   '2012',
#   '1973',
#   '2003',
#   '2005',
#   '2003',
#   '2012',
#   '1973',
#   '2003',
#   '2005',
#   '2003'],
#  "The Hitchhiker's Guide to the Galaxy ": [2007,
#   '2002',
#   '2007',
#   '2002',
#   '2005',
#   '2005',
#   '2007',
#   '2002',
#   '2005',
#   '2007',
#   '2007',
#   '2002',
#   '2007',
#   '2002',
#   '2005',
#   '2005',
#   '2008',
#   '2007',
#   '2002',
#   '2005',
#   '2007',
#   '2002',
#   '2005',
#   '2005',
#   '2007',
#   '2002',
#   '2005',
#   '2005',
#   '2008',
#   '1993',
#   '2012'],
#  'Robert Langdon ': [2006,
#   '2009',
#   '2006',
#   '2013',
#   '2006',
#   '2009',
#   '2006',
#   '2013',
#   '2006',
#   '2009',
#   '2006',
#   '2013',
#   '2006',
#   '2006',
#   '2006',
#   '2009',
#   '2006',
#   '2013',
#   '2006',
#   '2009',
#   '2006',
#   '2013',
#   '2006',
#   '2009',
#   '2006',
#   '2013',
#   '2006',
#   '2009',
#   '2006',
#   '2013',
#   '2017'],
#  "Alice's Adventures in Wonderland ": [2000,
#   '2000',
#   '2000',
#   '2000',
#   '2000',
#   '2000',
#   '1997',
#   '2000',
#   '2000',
#   '2000',
#   '1997'],
#  'Divergent ': [2012,
#   '2012',
#   '2013',
#   '2012',
#   '2012',
#   '2013',
#   '2012',
#   '2012',
#   '2013',
#   '2012',
#   '2012',
#   '2012',
#   '2012',
#   '2012',
#   '2013',
#   '2014',
#   '2012',
#   '2012',
#   '2012',
#   '2013',
#   '2012',
#   '2012',
#   '2013',
#   '2012',
#   '2012',
#   '2013',
#   '2014',
#   '2012',
#   '2013',
#   '2014',
#   '2014']}

# %%
Y = [] #Stores the nb_pages for all 10 bookseries

for k in range(len(sl)):
    
    yaxis = [dictionary_pages[sl[k]][0]] #initialize y with the nb_pages of the first book
    
    for i in range(1,len(dictionary_pages[sl[k]])):
        
        yaxis.append(dictionary_pages[sl[k]][i] + yaxis[i-1]) #Add the cumulative nb_pages to y
        
    Y.append(yaxis)

# %%
Y
# Out:
# [[374,
#   1529,
#   1920,
#   2310,
#   2684,
#   3839,
#   4230,
#   4620,
#   4994,
#   6149,
#   6540,
#   6930,
#   7304,
#   7678,
#   8052,
#   9207,
#   9598,
#   9972,
#   11127,
#   11518,
#   11908,
#   12282,
#   13437,
#   13828,
#   14218,
#   14592,
#   15747,
#   16138,
#   16528,
#   16902,
#   18057,
#   18448,
#   18838],
#  [870,
#   1179,
#   1938,
#   2373,
#   3107,
#   3759,
#   4100,
#   8200,
#   9070,
#   9379,
#   10138,
#   10573,
#   11307,
#   11959,
#   12300,
#   16400,
#   17270,
#   17579,
#   18338,
#   18773,
#   19507,
#   20159,
#   20500,
#   24600,
#   25470,
#   26340,
#   26649,
#   27408,
#   27843,
#   28713,
#   29022,
#   29781,
#   30216,
#   30950,
#   31602,
#   31943,
#   32813,
#   33122,
#   33881,
#   34316,
#   35050,
#   35702,
#   36043,
#   40143,
#   40486,
#   41986,
#   42856,
#   43165,
#   43924,
#   44359,
#   45093,
#   45745,
#   46086,
#   50186,
#   51056,
#   51365,
#   52124,
#   52559,
#   53293,
#   53945,
#   54286,
#   58386,
#   59256,
#   59565,
#   60324,
#   60759,
#   61493,
#   62145,
#   62486,
#   66586,
#   66929,
#   68429,
#   71771,
#   71775],
#  [324, 648, 972, 1296, 1620, 1944, 2268, 2592, 2916, 3240, 3549],
#  [501,
#   2191,
#   2692,
#   4382,
#   4560,
#   5189,
#   5945,
#   6508,
#   7009,
#   8699,
#   9200,
#   9701,
#   10202,
#   10703,
#   12393,
#   12571,
#   13200,
#   13956,
#   14519,
#   15020,
#   16710,
#   17211,
#   18901,
#   19079,
#   19580,
#   21270,
#   21448,
#   22077,
#   22833,
#   23396,
#   24134],
#  [767,
#   973,
#   1221,
#   1509,
#   1733,
#   1976,
#   2216,
#   2983,
#   3189,
#   3437,
#   3725,
#   3949,
#   4192,
#   4432,
#   5199,
#   5405,
#   5653,
#   5941,
#   6165,
#   6408,
#   6648,
#   7415,
#   8182,
#   8949,
#   9155,
#   9922,
#   10128,
#   10376,
#   10664,
#   10888,
#   11131,
#   11371,
#   12138,
#   12344,
#   12592,
#   12880,
#   13104,
#   13347,
#   13587,
#   14354,
#   14560,
#   14808,
#   15096,
#   15320,
#   15563,
#   15803,
#   16570,
#   16776,
#   17024,
#   17312,
#   17536,
#   17779,
#   18019],
#  [1728,
#   2255,
#   2653,
#   3869,
#   4254,
#   4576,
#   6304,
#   6831,
#   7229,
#   8445,
#   8830,
#   9152,
#   10880,
#   11407,
#   11805,
#   13021,
#   13406,
#   13728,
#   15456,
#   15983,
#   17711,
#   18238,
#   18636,
#   20364,
#   20891,
#   21289,
#   22505,
#   22827,
#   24555,
#   25082,
#   25480,
#   26696,
#   27018,
#   28746,
#   29273,
#   29671,
#   30887,
#   31209,
#   32937,
#   33464,
#   33862,
#   35078,
#   35400],
#  [193,
#   1008,
#   1201,
#   2016,
#   2266,
#   2490,
#   2683,
#   3498,
#   3748,
#   3941,
#   4134,
#   4949,
#   5142,
#   5957,
#   6207,
#   6431,
#   6656,
#   6849,
#   7664,
#   7914,
#   8107,
#   8922,
#   9172,
#   9396,
#   9589,
#   10404,
#   10654,
#   10878,
#   11103,
#   11391,
#   12394],
#  [489,
#   998,
#   1734,
#   2197,
#   2686,
#   3195,
#   3931,
#   4394,
#   4883,
#   5392,
#   6128,
#   6591,
#   7080,
#   7569,
#   8058,
#   8567,
#   9303,
#   9766,
#   10255,
#   10764,
#   11500,
#   11963,
#   12452,
#   12961,
#   13697,
#   14160,
#   14649,
#   15158,
#   15894,
#   16357,
#   16813],
#  [239, 478, 717, 956, 1195, 1434, 1530, 1769, 2008, 2247, 2343],
#  [487,
#   1012,
#   1538,
#   2025,
#   2550,
#   3076,
#   3563,
#   4088,
#   4614,
#   5101,
#   5588,
#   6113,
#   6600,
#   7125,
#   7651,
#   7859,
#   7902,
#   8389,
#   8914,
#   9440,
#   9927,
#   10452,
#   10978,
#   11465,
#   11990,
#   12516,
#   12724,
#   12767,
#   12822,
#   14438,
#   14478]]

# %%
dictionary_pages
# Out:
# {'The Hunger Games ': [374,
#   1155,
#   391,
#   390,
#   374,
#   1155,
#   391,
#   390,
#   374,
#   1155,
#   391,
#   390,
#   374,
#   374,
#   374,
#   1155,
#   391,
#   374,
#   1155,
#   391,
#   390,
#   374,
#   1155,
#   391,
#   390,
#   374,
#   1155,
#   391,
#   390,
#   374,
#   1155,
#   391,
#   390],
#  'Harry Potter ': [870,
#   309,
#   759,
#   435,
#   734,
#   652,
#   341,
#   4100,
#   870,
#   309,
#   759,
#   435,
#   734,
#   652,
#   341,
#   4100,
#   870,
#   309,
#   759,
#   435,
#   734,
#   652,
#   341,
#   4100,
#   870,
#   870,
#   309,
#   759,
#   435,
#   870,
#   309,
#   759,
#   435,
#   734,
#   652,
#   341,
#   870,
#   309,
#   759,
#   435,
#   734,
#   652,
#   341,
#   4100,
#   343,
#   1500,
#   870,
#   309,
#   759,
#   435,
#   734,
#   652,
#   341,
#   4100,
#   870,
#   309,
#   759,
#   435,
#   734,
#   652,
#   341,
#   4100,
#   870,
#   309,
#   759,
#   435,
#   734,
#   652,
#   341,
#   4100,
#   343,
#   1500,
#   3342,
#   4],
#  'To Kill a Mockingbird': [324,
#   324,
#   324,
#   324,
#   324,
#   324,
#   324,
#   324,
#   324,
#   324,
#   309],
#  'The Twilight Saga ': [501,
#   1690,
#   501,
#   1690,
#   178,
#   629,
#   756,
#   563,
#   501,
#   1690,
#   501,
#   501,
#   501,
#   501,
#   1690,
#   178,
#   629,
#   756,
#   563,
#   501,
#   1690,
#   501,
#   1690,
#   178,
#   501,
#   1690,
#   178,
#   629,
#   756,
#   563,
#   738],
#  'The Chronicles of Narnia Publication Order ': [767,
#   206,
#   248,
#   288,
#   224,
#   243,
#   240,
#   767,
#   206,
#   248,
#   288,
#   224,
#   243,
#   240,
#   767,
#   206,
#   248,
#   288,
#   224,
#   243,
#   240,
#   767,
#   767,
#   767,
#   206,
#   767,
#   206,
#   248,
#   288,
#   224,
#   243,
#   240,
#   767,
#   206,
#   248,
#   288,
#   224,
#   243,
#   240,
#   767,
#   206,
#   248,
#   288,
#   224,
#   243,
#   240,
#   767,
#   206,
#   248,
#   288,
#   224,
#   243,
#   240],
#  'The Lord of the Rings ': [1728,
#   527,
#   398,
#   1216,
#   385,
#   322,
#   1728,
#   527,
#   398,
#   1216,
#   385,
#   322,
#   1728,
#   527,
#   398,
#   1216,
#   385,
#   322,
#   1728,
#   527,
#   1728,
#   527,
#   398,
#   1728,
#   527,
#   398,
#   1216,
#   322,
#   1728,
#   527,
#   398,
#   1216,
#   322,
#   1728,
#   527,
#   398,
#   1216,
#   322,
#   1728,
#   527,
#   398,
#   1216,
#   322],
#  "The Hitchhiker's Guide to the Galaxy ": [193,
#   815,
#   193,
#   815,
#   250,
#   224,
#   193,
#   815,
#   250,
#   193,
#   193,
#   815,
#   193,
#   815,
#   250,
#   224,
#   225,
#   193,
#   815,
#   250,
#   193,
#   815,
#   250,
#   224,
#   193,
#   815,
#   250,
#   224,
#   225,
#   288,
#   1003],
#  'Robert Langdon ': [489,
#   509,
#   736,
#   463,
#   489,
#   509,
#   736,
#   463,
#   489,
#   509,
#   736,
#   463,
#   489,
#   489,
#   489,
#   509,
#   736,
#   463,
#   489,
#   509,
#   736,
#   463,
#   489,
#   509,
#   736,
#   463,
#   489,
#   509,
#   736,
#   463,
#   456],
#  "Alice's Adventures in Wonderland ": [239,
#   239,
#   239,
#   239,
#   239,
#   239,
#   96,
#   239,
#   239,
#   239,
#   96],
#  'Divergent ': [487,
#   525,
#   526,
#   487,
#   525,
#   526,
#   487,
#   525,
#   526,
#   487,
#   487,
#   525,
#   487,
#   525,
#   526,
#   208,
#   43,
#   487,
#   525,
#   526,
#   487,
#   525,
#   526,
#   487,
#   525,
#   526,
#   208,
#   43,
#   55,
#   1616,
#   40],
#  'The Mortal Instruments ': [485,
#   425,
#   546,
#   725,
#   541,
#   1520,
#   453,
#   485,
#   425,
#   546,
#   725,
#   541,
#   1520,
#   453,
#   485,
#   425,
#   546,
#   725,
#   541,
#   1520,
#   453,
#   485,
#   485,
#   425,
#   485,
#   425,
#   546,
#   725,
#   541,
#   1520,
#   453,
#   485,
#   425,
#   546,
#   725,
#   541,
#   1520,
#   453,
#   485,
#   425,
#   546,
#   725,
#   541,
#   1520,
#   453,
#   485,
#   425,
#   546,
#   725,
#   541,
#   1520,
#   453],
#  "Ender's Saga ": [324,
#   382,
#   324,
#   382,
#   324,
#   382,
#   324,
#   324,
#   324,
#   382,
#   592,
#   324,
#   382,
#   324,
#   382,
#   324,
#   382,
#   592,
#   370,
#   212],
#  'Anne of Green Gables ': [320,
#   304,
#   320,
#   304,
#   2088,
#   243,
#   320,
#   304,
#   320,
#   320,
#   320,
#   304,
#   2088,
#   243,
#   320,
#   304,
#   320,
#   304,
#   320,
#   304,
#   2088,
#   243],
#  'Dracula ': [488, 488, 488, 488, 488, 488, 488, 488, 488],
#  'Percy Jackson and the Olympians ': [375,
#   381,
#   361,
#   320,
#   279,
#   375,
#   381,
#   361,
#   320,
#   279,
#   1032,
#   375,
#   381,
#   361,
#   320,
#   279,
#   375,
#   375,
#   381,
#   361,
#   320,
#   279,
#   375,
#   381,
#   361,
#   320,
#   279,
#   1032,
#   151,
#   417,
#   375,
#   381,
#   361,
#   320,
#   279,
#   375,
#   381,
#   361,
#   320,
#   279,
#   1032,
#   375,
#   381,
#   361,
#   320,
#   279,
#   1032,
#   151,
#   417,
#   396,
#   416],
#  'A Song of Ice and Fire ': [835,
#   1177,
#   969,
#   1061,
#   1125,
#   835,
#   1177,
#   969,
#   1061,
#   1125,
#   835,
#   1177,
#   969,
#   1061,
#   1125,
#   835,
#   835,
#   1177,
#   969,
#   835,
#   1177,
#   969,
#   1061,
#   1125,
#   5216,
#   835,
#   1177,
#   969,
#   1061,
#   1125,
#   835,
#   1177,
#   969,
#   1061,
#   1125,
#   835,
#   1177,
#   969,
#   1061,
#   1125,
#   5216,
#   864,
#   nan,
#   nan],
#  'Time Quintet ': [218,
#   218,
#   750,
#   218,
#   218,
#   218,
#   218,
#   750,
#   203,
#   218,
#   218,
#   218,
#   750,
#   203,
#   278,
#   710,
#   1400,
#   211],
#  'Adventures of Tom and Huck ': [327,
#   244,
#   327,
#   244,
#   327,
#   244,
#   327,
#   327,
#   244,
#   327,
#   244,
#   327,
#   244,
#   327,
#   244,
#   327,
#   244],
#  "The Handmaid's Tale  ": [314, 314, 314, 314, 314, 314, 314, 314, 314],
#  'The Giver  ': [208,
#   208,
#   208,
#   208,
#   208,
#   208,
#   240,
#   169,
#   208,
#   208,
#   208,
#   240,
#   169],
#  'Catch-22 ': [453, 453, 453, 453, 453, 453, 453, 453, 453],
#  'Dune ': [661, 661, 661, 661, 661, 661, 661, 661, 661, 337, 587, 687],
#  'Kingsbridge ': [976,
#   1014,
#   976,
#   1014,
#   976,
#   1014,
#   976,
#   976,
#   976,
#   1014,
#   976,
#   1014,
#   976,
#   1014,
#   976,
#   1014],
#  'Sherlock Holmes ': [389,
#   1796,
#   256,
#   389,
#   1796,
#   256,
#   123,
#   389,
#   1796,
#   256,
#   389,
#   389,
#   389,
#   1796,
#   256,
#   123,
#   129,
#   389,
#   1796,
#   256,
#   123,
#   389,
#   1796,
#   256,
#   123,
#   389,
#   1796,
#   256,
#   123,
#   129,
#   636,
#   204,
#   546],
#  'Watership Down ': [478, 478, 478, 478, 478, 478, 478, 478, 478, 335],
#  'Little Women ': [449, 449, 449, 449, 449, 449, 449, 449, 449, 1064],
#  'Outlander ': [850,
#   963,
#   870,
#   928,
#   993,
#   1443,
#   850,
#   963,
#   870,
#   928,
#   993,
#   1443,
#   1149,
#   850,
#   963,
#   870,
#   928,
#   993,
#   1443,
#   850,
#   850,
#   850,
#   963,
#   870,
#   928,
#   993,
#   1443,
#   1149,
#   850,
#   963,
#   870,
#   928,
#   993,
#   1443,
#   850,
#   963,
#   870,
#   928,
#   993,
#   1443,
#   850,
#   963,
#   870,
#   928,
#   993,
#   1443,
#   1149,
#   825,
#   374],
#  'Millennium ': [465,
#   503,
#   566,
#   465,
#   503,
#   566,
#   465,
#   503,
#   566,
#   465,
#   465,
#   503,
#   566,
#   465,
#   503,
#   566,
#   465,
#   503,
#   566,
#   465,
#   503,
#   566,
#   465,
#   503,
#   566],
#  'The Color Purple Collection ': [304, 304, 304, 304, 304, 304, 304, 304, 304],
#  'The Brothers Karamazov ': [796, 796, 796, 796, 796, 796, 796, 796, 796, 974],
#  'Frank McCourt ': [452, 452, 452, 452, 452, 452, 452, 452, 452],
#  'Vampire Academy ': [332,
#   443,
#   327,
#   503,
#   594,
#   489,
#   332,
#   443,
#   327,
#   503,
#   594,
#   489,
#   1120,
#   332,
#   443,
#   327,
#   503,
#   594,
#   489,
#   332,
#   332,
#   443,
#   327,
#   503,
#   594,
#   489,
#   332,
#   443,
#   327,
#   503,
#   594,
#   489,
#   1120,
#   332,
#   443,
#   327,
#   503,
#   594,
#   489,
#   332,
#   443,
#   327,
#   503,
#   594,
#   489,
#   332,
#   443,
#   327,
#   503,
#   594,
#   489,
#   1120,
#   1680,
#   351,
#   3],
#  'His Dark Materials ': [399,
#   1088,
#   467,
#   370,
#   399,
#   1088,
#   467,
#   370,
#   399,
#   1088,
#   467,
#   370,
#   399,
#   399,
#   1088,
#   399,
#   1088,
#   467,
#   370,
#   399,
#   1088,
#   467,
#   370,
#   399,
#   1088,
#   467,
#   370,
#   399,
#   1088,
#   467,
#   370,
#   1102,
#   80,
#   104],
#  'The Notebook ': [227,
#   227,
#   276,
#   227,
#   276,
#   227,
#   227,
#   227,
#   276,
#   227,
#   276,
#   227,
#   276,
#   227,
#   276],
#  'Winnie-the-Pooh ': [145, 145, 145, 145, 145, 145, 180, 145, 145, 145, 180],
#  'The Vampire Chronicles ': [342,
#   481,
#   448,
#   342,
#   481,
#   448,
#   354,
#   342,
#   481,
#   448,
#   342,
#   342,
#   481,
#   342,
#   481,
#   448,
#   354,
#   457,
#   342,
#   481,
#   448,
#   342,
#   481,
#   448,
#   354,
#   342,
#   481,
#   448,
#   354,
#   457,
#   468,
#   774,
#   752,
#   9,
#   451],
#  'The Infernal Devices ': [481,
#   567,
#   498,
#   481,
#   567,
#   498,
#   481,
#   567,
#   498,
#   481,
#   567,
#   498,
#   481,
#   567,
#   498,
#   481,
#   567,
#   498,
#   481,
#   567,
#   498,
#   481,
#   567,
#   498,
#   1520],
#  'The Kingkiller Chronicle ': [662,
#   994,
#   662,
#   994,
#   662,
#   994,
#   662,
#   662,
#   994,
#   662,
#   994,
#   662,
#   994,
#   662,
#   994,
#   159,
#   nan],
#  'The Shining ': [659, 659, 659, 659, 659, 531, 659, 659, 659, 531],
#  'The Inheritance Cycle ': [503,
#   704,
#   748,
#   849,
#   503,
#   704,
#   748,
#   849,
#   503,
#   704,
#   748,
#   849,
#   503,
#   503,
#   704,
#   748,
#   849,
#   1952,
#   503,
#   704,
#   748,
#   849,
#   503,
#   704,
#   748,
#   849,
#   503,
#   704,
#   748,
#   849,
#   1952,
#   32],
#  'Charlie Bucket ': [176, 176, 176, 176, 176, 176, 176, 176],
#  'Duluoz Legend': [307,
#   307,
#   244,
#   307,
#   307,
#   307,
#   244,
#   307,
#   307,
#   307,
#   244,
#   256,
#   194,
#   109],
#  'El cementerio de los libros olvidados ': [487,
#   487,
#   531,
#   487,
#   487,
#   487,
#   531,
#   487,
#   487,
#   487,
#   531],
#  'The Godfather ': [448, 448, 448, 448, 448, 448, 448, 448],
#  'The Five People You Meet in Heaven ': [196,
#   196,
#   196,
#   196,
#   196,
#   196,
#   196,
#   196],
#  'Hush, Hush ': [391,
#   432,
#   448,
#   391,
#   432,
#   448,
#   464,
#   391,
#   432,
#   448,
#   464,
#   391,
#   391,
#   432,
#   448,
#   464,
#   391,
#   432,
#   448,
#   464,
#   391,
#   432,
#   448,
#   464,
#   391,
#   432,
#   448,
#   464],
#  'The Cat in the Hat ': [61, 61, 61, 61, 61, 63, 61, 61, 61, 63],
#  'American Gods ': [635,
#   635,
#   387,
#   635,
#   635,
#   635,
#   387,
#   635,
#   635,
#   387,
#   635,
#   387,
#   635],
#  'Lonesome Dove ': [960, 960, 960, 960, 960, 960, 960, 960, 716, 464],
#  'Holes ': [233, 233, 233, 233, 233, 233, 233, 233, 257],
#  'Watchmen ': [416, 416, 416, 416, 416, 416, 416, 416],
#  'Little House ': [2700,
#   335,
#   198,
#   2700,
#   335,
#   198,
#   2700,
#   335,
#   198,
#   2700,
#   2700,
#   335,
#   198,
#   289,
#   2700,
#   335,
#   198,
#   2700,
#   335,
#   198,
#   2700,
#   335,
#   198,
#   289,
#   126,
#   999],
#  'La Divina Commedia ': [798,
#   490,
#   798,
#   490,
#   798,
#   490,
#   798,
#   798,
#   490,
#   798,
#   490,
#   798,
#   490,
#   798,
#   490],
#  'All Quiet on the Western Front/The Road Back ': [296,
#   296,
#   296,
#   296,
#   296,
#   296,
#   296,
#   296],
#  'The Hobbit': [366, 366, 366, 366, 366, 366, 366, 366],
#  "The D'Artagnan Romances ": [625,
#   625,
#   625,
#   625,
#   625,
#   625,
#   625,
#   625,
#   470,
#   452],
#  'Oz ': [154, 154, 154, 154, 154, 154, 154, 154, 1755, 288, 432],
#  'Over the Moon ': [32, 32, 32, 32, 32, 48, 32, 32, 32, 48],
#  'House of Earth ': [418, 418, 418, 418, 418, 418, 418, 418],
#  'Avalon ': [1009, 1009, 1009, 1009, 1009, 1009, 1009, 1009, 460, 360],
#  'The Maze Runner ': [384,
#   362,
#   325,
#   384,
#   362,
#   325,
#   384,
#   362,
#   325,
#   384,
#   384,
#   362,
#   325,
#   327,
#   384,
#   362,
#   325,
#   384,
#   362,
#   325,
#   384,
#   362,
#   325,
#   327,
#   4],
#  'Fifty Shades ': [356,
#   532,
#   579,
#   356,
#   532,
#   579,
#   1859,
#   356,
#   532,
#   579,
#   356,
#   356,
#   532,
#   579,
#   1859,
#   356,
#   532,
#   579,
#   356,
#   532,
#   579,
#   356,
#   532,
#   579,
#   1859],
#  "Earth's Children  ": [516,
#   516,
#   544,
#   516,
#   516,
#   516,
#   544,
#   688,
#   516,
#   516,
#   544,
#   516,
#   544,
#   688,
#   784,
#   nan,
#   512],
#  'The Wicked Years ': [406, 406, 406, 406, 406, 406, 406, 406, 312, nan],
#  'Asian Saga: Chronological Order ': [1152,
#   1152,
#   734,
#   1152,
#   1152,
#   1152,
#   734,
#   1376,
#   1152,
#   1152,
#   1152,
#   734,
#   1376,
#   368,
#   1236],
#  'Hercule Poirot ': [347,
#   347,
#   214,
#   288,
#   347,
#   214,
#   288,
#   347,
#   347,
#   214,
#   288,
#   121,
#   347,
#   214,
#   288,
#   347,
#   214,
#   288,
#   347,
#   214,
#   288,
#   121,
#   220,
#   224,
#   384,
#   336,
#   335,
#   317,
#   244,
#   324,
#   264,
#   0,
#   224,
#   265,
#   352,
#   8,
#   9,
#   336,
#   322,
#   304],
#  'The Plantagenet and Tudor Novels ': [661,
#   661,
#   661,
#   661,
#   661,
#   390,
#   661,
#   661,
#   661,
#   390,
#   412,
#   544,
#   417,
#   441],
#  'Jurassic Park ': [466, 466, 466, 466, 466, 448, 466, 466, 466, 448, 811],
#  'Fallen ': [452,
#   452,
#   452,
#   452,
#   420,
#   466,
#   452,
#   452,
#   420,
#   452,
#   452,
#   452,
#   420,
#   466,
#   452,
#   452,
#   420,
#   452,
#   452,
#   420,
#   452,
#   452,
#   420,
#   466],
#  'Middle-earth Universe': [386,
#   386,
#   313,
#   386,
#   386,
#   386,
#   313,
#   386,
#   386,
#   386,
#   313,
#   178,
#   nan],
#  'Beloved Trilogy ': [324, 324, 324, 324, 324, 324, 324, 324],
#  'The Selection ': [336,
#   323,
#   336,
#   336,
#   323,
#   336,
#   336,
#   323,
#   336,
#   336,
#   336,
#   323,
#   336,
#   342,
#   336,
#   323,
#   336,
#   336,
#   323,
#   336,
#   336,
#   323,
#   336,
#   342,
#   11,
#   1344,
#   724],
#  'Throne of Glass ': [406,
#   420,
#   565,
#   648,
#   406,
#   420,
#   565,
#   648,
#   689,
#   448,
#   406,
#   420,
#   565,
#   648,
#   689,
#   406,
#   406,
#   420,
#   565,
#   648,
#   689,
#   448,
#   984,
#   406,
#   420,
#   565,
#   648,
#   689,
#   448,
#   406,
#   420,
#   565,
#   648,
#   689,
#   448,
#   406,
#   420,
#   565,
#   648,
#   689,
#   448,
#   984,
#   660,
#   nan,
#   433,
#   418,
#   562,
#   648,
#   404,
#   689],
#  'The Heroes of Olympus ': [553,
#   513,
#   586,
#   597,
#   553,
#   513,
#   586,
#   597,
#   516,
#   553,
#   513,
#   586,
#   597,
#   516,
#   553,
#   553,
#   513,
#   586,
#   597,
#   516,
#   553,
#   513,
#   586,
#   597,
#   516,
#   553,
#   513,
#   586,
#   597,
#   516,
#   553,
#   513,
#   586,
#   597,
#   516],
#  'Hannibal Lecter ': [421,
#   421,
#   454,
#   421,
#   421,
#   421,
#   454,
#   564,
#   421,
#   421,
#   421,
#   454,
#   564],
#  'The Wolves of Mercy Falls ': [392,
#   362,
#   392,
#   362,
#   390,
#   392,
#   362,
#   392,
#   392,
#   362,
#   390,
#   392,
#   362,
#   392,
#   362,
#   390,
#   392,
#   362,
#   390,
#   1150],
#  'Uglies  ': [425,
#   370,
#   425,
#   370,
#   384,
#   417,
#   425,
#   370,
#   384,
#   425,
#   425,
#   370,
#   384,
#   417,
#   425,
#   370,
#   384,
#   425,
#   370,
#   384,
#   425,
#   370,
#   384,
#   417],
#  'Ella Enchanted ': [232, 232, 232, 232, 232, 232, 232, 232, 326, 352],
#  'ねじまき鳥クロニクル ': [607, 607, 607, 607, 607, 607, 607, 607],
#  'The Lunar Chronicles ': [400,
#   454,
#   552,
#   400,
#   454,
#   552,
#   827,
#   400,
#   454,
#   552,
#   400,
#   400,
#   454,
#   552,
#   827,
#   400,
#   454,
#   552,
#   400,
#   454,
#   552,
#   827,
#   400,
#   454,
#   552,
#   827],
#  'The Green Mile ': [592, 592, 592, 592, 592, 592, 592, 592, 92],
#  'Blindness ': [349, 349, 349, 349, 349, 349, 349, 349],
#  'House of Night ': [306,
#   310,
#   338,
#   307,
#   323,
#   319,
#   306,
#   310,
#   338,
#   307,
#   323,
#   319,
#   323,
#   290,
#   306,
#   310,
#   338,
#   307,
#   323,
#   319,
#   323,
#   306,
#   306,
#   310,
#   338,
#   307,
#   323,
#   319,
#   323,
#   290,
#   306,
#   310,
#   338,
#   307,
#   323,
#   319,
#   323,
#   306,
#   310,
#   338,
#   307,
#   323,
#   319,
#   323,
#   290,
#   306,
#   310,
#   338,
#   307,
#   323,
#   319,
#   323,
#   290,
#   310,
#   nan,
#   3920,
#   1264],
#  'Del Valle Family ': [448, 448, 448, 448, 448, 432, 448, 448, 448, 432],
#  'Calvin and Hobbes': [1456,
#   1456,
#   1456,
#   1456,
#   1456,
#   254,
#   208,
#   1456,
#   1456,
#   1456,
#   254,
#   208,
#   128],
#  "Howl's Moving Castle ": [329, 329, 329, 329, 329, 329, 329, 329],
#  'Delirium ': [441,
#   441,
#   375,
#   441,
#   375,
#   441,
#   441,
#   375,
#   391,
#   441,
#   375,
#   441,
#   375,
#   441,
#   375,
#   391],
#  'Beautiful ': [319,
#   319,
#   448,
#   319,
#   448,
#   319,
#   319,
#   448,
#   319,
#   448,
#   319,
#   448,
#   319,
#   448],
#  'The Once and Future King ': [639,
#   639,
#   639,
#   639,
#   639,
#   352,
#   639,
#   639,
#   639,
#   352,
#   823,
#   208,
#   160,
#   269,
#   291],
#  'London Below,  The World of Neverwhere ': [370,
#   370,
#   370,
#   370,
#   370,
#   370,
#   370],
#  'Inkworld ': [563,
#   563,
#   635,
#   699,
#   563,
#   563,
#   635,
#   699,
#   563,
#   563,
#   635,
#   563,
#   635,
#   699],
#  'All Creatures Great and Small ': [437,
#   437,
#   378,
#   437,
#   437,
#   378,
#   437,
#   437,
#   437,
#   378,
#   820,
#   384,
#   370,
#   229],
#  'Graceling Realm ': [471,
#   471,
#   480,
#   471,
#   480,
#   471,
#   480,
#   576,
#   471,
#   480,
#   471,
#   480,
#   471,
#   480,
#   576],
#  'Foundation Publication Order ': [244,
#   244,
#   244,
#   244,
#   256,
#   244,
#   244,
#   244,
#   256,
#   679,
#   256,
#   nan],
#  'ノルウェイの森': [296, 296, 296, 296, 296, 296, 296],
#  '海辺のカフカ': [467, 467, 467, 467, 467, 467, 467],
#  'Heidi ': [352, 352, 352, 352, 352, 352, 352],
#  'Whistle Stop, AL ': [416, 416, 416, 416, 416, 416, 416],
#  'Sookie Stackhouse ': [292,
#   291,
#   274,
#   291,
#   292,
#   291,
#   274,
#   291,
#   324,
#   295,
#   359,
#   323,
#   312,
#   292,
#   291,
#   274,
#   291,
#   324,
#   295,
#   359,
#   323,
#   312,
#   292,
#   291,
#   274,
#   291,
#   324,
#   295,
#   359,
#   323,
#   312,
#   311,
#   292,
#   291,
#   274,
#   291,
#   324,
#   295,
#   359,
#   323,
#   312,
#   292,
#   291,
#   274,
#   291,
#   324,
#   295,
#   359,
#   323,
#   312,
#   292,
#   291,
#   274,
#   291,
#   324,
#   295,
#   359,
#   323,
#   312,
#   311,
#   800],
#  'Ready Player One ': [374, 374, 374, 374, 374, 374, 374],
#  'A Court of Thorns and Roses ': [626,
#   419,
#   626,
#   419,
#   699,
#   626,
#   419,
#   699,
#   626,
#   419,
#   699,
#   626,
#   419,
#   699,
#   626,
#   419,
#   699,
#   626,
#   419,
#   699,
#   229],
#  'Big Little Golden Books': [32, 32, 32, 32, 32, 32, 32],
#  'The African Trilogy ': [209, 209, 209, 209, 209, 209, 209, 230],
#  'Bridget Jones ': [288, 288, 288, 288, 288, 288, 288],
#  'The Power of One ': [544, 544, 544, 544, 544, 544, 544],
#  'The Chronicles of Narnia Chronological Order ': [221,
#   221,
#   221,
#   221,
#   221,
#   221,
#   221,
#   nan],
#  'Jake Brigance ': [515, 515, 515, 515, 515, 515, 515],
#  'The Dark Tower ': [231,
#   231,
#   1050,
#   845,
#   463,
#   422,
#   231,
#   1050,
#   845,
#   463,
#   231,
#   1050,
#   845,
#   463,
#   422,
#   231,
#   1050,
#   845,
#   463,
#   231,
#   1050,
#   845,
#   463,
#   231,
#   1050,
#   845,
#   463,
#   422,
#   931,
#   1008],
#  'Blade Runner ': [258, 258, 258, 258, 258, 258, 258],
#  'The Stormlight Archive ': [1007,
#   1087,
#   1007,
#   1087,
#   1007,
#   1087,
#   1007,
#   1087,
#   1243,
#   1007,
#   1087,
#   1007,
#   1087,
#   1007,
#   1087,
#   1243,
#   1258,
#   272,
#   530,
#   272],
#  'Legend ': [305,
#   369,
#   371,
#   305,
#   369,
#   371,
#   305,
#   369,
#   371,
#   305,
#   369,
#   371,
#   305,
#   369,
#   371,
#   305,
#   369,
#   371,
#   305,
#   369,
#   371,
#   38,
#   376,
#   1088],
#  'Me Before You ': [369, 369, 369, 369, 369, 369, 369],
#  'If I Stay ': [201,
#   297,
#   201,
#   297,
#   201,
#   297,
#   201,
#   297,
#   201,
#   297,
#   201,
#   297,
#   201,
#   297],
#  'V for Vendetta ': [296, 296, 296, 296, 296, 296, 296],
#  'Wonder ': [315, 315, 315, 315, 315, 315, 315],
#  'Mistborn ': [544,
#   544,
#   572,
#   590,
#   544,
#   572,
#   544,
#   572,
#   590,
#   544,
#   572,
#   590,
#   544,
#   572,
#   590,
#   544,
#   572,
#   590,
#   332],
#  'Beautiful Creatures ': [563,
#   563,
#   503,
#   563,
#   563,
#   503,
#   516,
#   563,
#   563,
#   563,
#   503,
#   516,
#   456,
#   75],
#  'Black Dagger Brotherhood ': [393,
#   448,
#   464,
#   528,
#   480,
#   527,
#   393,
#   448,
#   464,
#   528,
#   480,
#   527,
#   528,
#   560,
#   393,
#   448,
#   464,
#   528,
#   480,
#   527,
#   528,
#   393,
#   448,
#   464,
#   528,
#   480,
#   527,
#   528,
#   560,
#   512,
#   608,
#   393,
#   448,
#   464,
#   528,
#   480,
#   527,
#   528,
#   393,
#   448,
#   464,
#   528,
#   480,
#   527,
#   528,
#   560,
#   393,
#   448,
#   464,
#   528,
#   480,
#   527,
#   528,
#   560,
#   512,
#   608,
#   572,
#   nan,
#   467,
#   508,
#   509,
#   416,
#   463],
#  'The Wheel of Time ': [814,
#   814,
#   624,
#   705,
#   1007,
#   814,
#   814,
#   624,
#   705,
#   1007,
#   783,
#   1011,
#   863,
#   814,
#   814,
#   814,
#   624,
#   705,
#   1007,
#   783,
#   1011,
#   863,
#   912,
#   912,
#   860,
#   304,
#   nan,
#   11095],
#  'Maus ': [296, 296, 296, 296, 296, 296, 296],
#  'Dave Pelzer ': [184, 184, 184, 184, 184, 184, 184],
#  'Stargirl ': [186, 186, 186, 186, 186, 186, 186, 288],
#  'Lux ': [335,
#   335,
#   394,
#   421,
#   374,
#   335,
#   394,
#   421,
#   335,
#   394,
#   421,
#   374,
#   533,
#   335,
#   394,
#   421,
#   335,
#   394,
#   421,
#   374,
#   335,
#   394,
#   421,
#   374,
#   533,
#   807,
#   352,
#   354],
#  'The Martian ': [384, 384, 384, 384, 384, 384, 384],
#  'Phaedrus ': [540, 540, 540, 540, 540, 540, 540],
#  'Shatter Me ': [338,
#   421,
#   461,
#   338,
#   421,
#   461,
#   338,
#   421,
#   461,
#   338,
#   421,
#   461,
#   338,
#   421,
#   461,
#   338,
#   421,
#   461,
#   338,
#   421,
#   461,
#   111,
#   112],
#  'Great Plains Trilogy ': [232, 232, 232, 232, 159, 232, 232, 232, 159, 314],
#  'Robinson Crusoe ': [320, 320, 320, 320, 320, 320, 320],
#  'The Six of Crows Trilogy ': [465,
#   536,
#   465,
#   536,
#   465,
#   536,
#   465,
#   536,
#   465,
#   536,
#   465,
#   536,
#   465,
#   536],
#  'Como agua para chocolate ': [222, 222, 222, 222, 222, 222, 222],
#  'Daughter of Smoke & Bone ': [418,
#   418,
#   517,
#   418,
#   418,
#   517,
#   418,
#   418,
#   418,
#   517,
#   613,
#   1584],
#  'The Immortals ': [301,
#   301,
#   284,
#   301,
#   301,
#   284,
#   339,
#   320,
#   362,
#   301,
#   301,
#   284,
#   301,
#   284,
#   339,
#   320,
#   358],
#  'Anna and the French Kiss ': [372,
#   372,
#   372,
#   372,
#   338,
#   372,
#   372,
#   372,
#   338,
#   339],
#  "Goethe's Faust ": [327, 327, 327, 327, 503, 327, 327, 327, 503, 304],
#  'Maximum Ride ': [445,
#   445,
#   409,
#   405,
#   309,
#   445,
#   445,
#   409,
#   405,
#   309,
#   256,
#   309,
#   298,
#   445,
#   445,
#   409,
#   405,
#   445,
#   409,
#   405,
#   309,
#   256,
#   309,
#   298,
#   368],
#  "Miss Peregrine's Peculiar Children ": [352,
#   352,
#   428,
#   352,
#   352,
#   428,
#   352,
#   352,
#   352,
#   428,
#   465,
#   170,
#   496],
#  'Matched ': [369, 369, 369, 369, 367, 512, 369, 369, 369, 367, 512, 1322],
#  'Dollanganger ': [389, 389, 389, 389, 389, 389, 389, 439, 408, 376, nan],
#  'Hopeless ': [410, 410, 321, 410, 410, 321, 410, 410, 410, 321, 176],
#  'The Scarlet Pimpernel publication order ': [182,
#   182,
#   182,
#   182,
#   182,
#   182,
#   182],
#  'Reuven Malther ': [304, 304, 304, 304, 304, 304, 304],
#  'Artemis Fowl ': [396, 396, 396, 396, 352, 396, 396, 396, 352, 398, 385, 187],
#  'Pippi Långstrump ': [160, 160, 160, 160, 160, 160, 160, 126, 140],
#  'Hogwarts Library': [109,
#   109,
#   128,
#   109,
#   109,
#   128,
#   56,
#   109,
#   109,
#   109,
#   128,
#   56,
#   240,
#   296],
#  'Shantaram ': [936, 936, 936, 936, 936, 936, 936],
#  'The Host ': [620, 620, 620, 620, 620, 620, 620],
#  'Sprawl ': [292, 292, 292, 292, 292, 292, 292, 308, 297],
#  'Ya Yas ': [383, 383, 383, 383, 383, 383, 383],
#  "Maya Angelou's Autobiography ": [289,
#   289,
#   289,
#   289,
#   289,
#   289,
#   289,
#   201,
#   224],
#  'Robot ': [224, 224, 224, 224, 224, 224, 224, 512, 352, 684, 290, 500, 224],
#  'Claudius ': [468, 468, 468, 468, 468, 468, 468],
#  'Platonis opera ': [416, 416, 416, 416, 416, 416, 416],
#  'The Exorcist ': [385, 385, 385, 385, 385, 385, 385],
#  'Quantum Roots ': [296,
#   296,
#   262,
#   296,
#   296,
#   262,
#   296,
#   296,
#   262,
#   296,
#   296,
#   262,
#   296,
#   296,
#   262,
#   296,
#   296,
#   262,
#   296,
#   296,
#   262],
#  'Aristotle and Dante ': [359, 359, 359, 359, 359, 359, 359],
#  'The 5th Wave ': [457, 457, 457, 457, 457, 457, 457, 320],
#  'The Iron Fey ': [363,
#   363,
#   384,
#   359,
#   400,
#   363,
#   363,
#   384,
#   359,
#   400,
#   363,
#   363,
#   384,
#   359,
#   363,
#   384,
#   359,
#   400,
#   72,
#   67,
#   1504],
#  'Bloodlines ': [421,
#   421,
#   418,
#   401,
#   421,
#   418,
#   421,
#   418,
#   401,
#   420,
#   320,
#   421,
#   418,
#   401,
#   421,
#   418,
#   401,
#   421,
#   418,
#   401,
#   420,
#   320,
#   380,
#   308,
#   300],
#  'Sword of Truth ': [836,
#   836,
#   836,
#   836,
#   785,
#   703,
#   836,
#   836,
#   836,
#   785,
#   703,
#   822,
#   2405,
#   2405,
#   502],
#  'Gemma Doyle ': [403, 403, 403, 403, 548, 819, 403, 403, 403, 548, 819],
#  'Crossfire ': [334,
#   334,
#   338,
#   334,
#   338,
#   334,
#   338,
#   356,
#   334,
#   338,
#   334,
#   338,
#   334,
#   338,
#   356,
#   464],
#  'Lives of the Mayfair Witches ': [1207, 1207, 1207, 1207, 1207, 1207, 1207],
#  'World War Z': [342, 342, 342, 342, 342, 342, 342],
#  'Darkest Powers ': [390,
#   390,
#   360,
#   391,
#   390,
#   360,
#   391,
#   390,
#   360,
#   391,
#   390,
#   360,
#   391,
#   390,
#   360,
#   391,
#   390,
#   360,
#   391,
#   443],
#  'Chocolat ': [306, 306, 306, 306, 306, 306, 306, 453],
#  'Red Queen ': [383, 383, 383, 383, 444, 383, 383, 383, 444, 528, 400],
#  'Night Huntress ': [358,
#   358,
#   357,
#   342,
#   355,
#   358,
#   357,
#   358,
#   357,
#   342,
#   355,
#   357,
#   358,
#   357,
#   342,
#   358,
#   357,
#   342,
#   355,
#   358,
#   357,
#   342,
#   355,
#   357,
#   358,
#   106],
#  'Perfect Chemistry ': [368,
#   368,
#   336,
#   368,
#   368,
#   336,
#   319,
#   368,
#   368,
#   336,
#   368,
#   336,
#   319],
#  'Unwind Dystology ': [337, 337, 337, 337, 337, 337, 337, 416],
#  'All Souls Trilogy ': [579, 579, 579, 579, 584, 579, 579, 579, 584, 561],
#  'Mark Renton ': [430,
#   430,
#   548,
#   430,
#   548,
#   430,
#   548,
#   600,
#   430,
#   548,
#   430,
#   548,
#   430,
#   548,
#   600,
#   288],
#  'Space Odyssey ': [297, 297, 297, 297, 297, 297, 297, nan],
#  'Cannery Row ': [181, 181, 181, 181, 181, 181, 181],
#  'À la recherche du temps perdu ': [444,
#   444,
#   444,
#   444,
#   4211,
#   444,
#   444,
#   444,
#   4211],
#  'Dark-Hunter ': [728,
#   728,
#   728,
#   728,
#   343,
#   362,
#   728,
#   728,
#   728,
#   343,
#   362,
#   309,
#   408,
#   836,
#   320,
#   359,
#   282,
#   320,
#   343],
#  'Ishmael  ': [338, 338, 338, 338, 338, 338, 338, 352],
#  'Mara Dyer ': [456, 456, 545, 456, 456, 545, 456, 456, 456, 545, 470],
#  'Lorien Legacies ': [440,
#   440,
#   440,
#   440,
#   406,
#   372,
#   440,
#   440,
#   440,
#   406,
#   372,
#   1648],
#  'Penryn & the End of Days ': [288,
#   288,
#   288,
#   288,
#   320,
#   288,
#   288,
#   288,
#   320,
#   344,
#   1200],
#  'Wemmicksville ': [32, 32, 32, 32, 32, 32, 32, 31],
#  'The Old Kingdom ': [491, 491, 491, 491, 491, 491, 491],
#  'The Bronze Horseman ': [912, 912, 912, 912, 559, 912, 912, 912, 559, 742],
#  'The Books of Bayern ': [383,
#   383,
#   383,
#   383,
#   317,
#   383,
#   383,
#   383,
#   317,
#   290,
#   1120],
#  'The Darkest Minds ': [488, 488, 488, 488, 507, 488, 488, 488, 507, 110, 569],
#  'The Christmas Books ': [104, 104, 104, 104, 104, 104, 104, 304, 84],
#  'Wicked Lovely ': [328,
#   328,
#   325,
#   328,
#   328,
#   325,
#   389,
#   328,
#   328,
#   328,
#   325,
#   389,
#   340],
#  'P.S. I Love You ': [501, 501, 501, 501, 501, 501, 501],
#  'The Raven Cycle ': [409,
#   409,
#   439,
#   409,
#   409,
#   439,
#   439,
#   391,
#   409,
#   409,
#   409,
#   439,
#   439,
#   391],
#  'Slammed ': [354, 354, 230, 354, 354, 230, 304, 354, 354, 230, 354, 230, 304],
#  'The Last Unicorn ': [294, 294, 294, 294, 294, 294, 294],
#  'A Series of Unfortunate Events ': [176,
#   176,
#   176,
#   176,
#   192,
#   176,
#   176,
#   176,
#   192,
#   259,
#   337,
#   214,
#   221,
#   337,
#   194,
#   323,
#   3417,
#   353,
#   1448],
#  'Hyperion Cantos ': [482, 482, 482, 482, 517, 482, 482, 482, 517, 992, 779],
#  'Greer Family ': [232, 232, 232, 232, 232, 232, 232],
#  'The Kane Chronicles ': [516,
#   516,
#   452,
#   406,
#   516,
#   516,
#   452,
#   406,
#   516,
#   516,
#   516,
#   452,
#   406],
#  "A Dog's Purpose ": [319, 319, 319, 319, 319, 319, 319, 336],
#  'Poison Study ': [427, 427, 427, 427, 392, 441, 427, 427, 427, 392, 441],
#  'The Secret ': [199, 199, 199, 199, 199, 199, 199, 240, 336],
#  'Left Behind ': [342,
#   342,
#   342,
#   342,
#   342,
#   342,
#   342,
#   413,
#   381,
#   432,
#   480,
#   nan,
#   389,
#   395,
#   432,
#   424,
#   399],
#  'Thursday Next ': [374, 374, 374, 374, 374, 374, 374, 363, 362],
#  'The Talisman ': [656, 656, 656, 656, 656, 656, 656],
#  'Gone ': [560, 560, 560, 560, 560, 560, 560, 447, 509, 590, 494, 411],
#  'Chaos Walking ': [512, 512, 512, 512, 553, 643, 512, 512, 512, 553, 643],
#  'Fever ': [608,
#   309,
#   608,
#   309,
#   386,
#   327,
#   303,
#   608,
#   309,
#   386,
#   327,
#   608,
#   309,
#   386,
#   327,
#   303,
#   608,
#   309,
#   386,
#   327,
#   608,
#   309,
#   386,
#   327,
#   303,
#   608,
#   309,
#   386,
#   327,
#   303,
#   512,
#   512],
#  'The Civil War Trilogy ': [345, 345, 345, 345, 345, 345, 345, 640],
#  'Jason Bourne ': [566, 566, 566, 566, 566, 566, 566, 725],
#  'The Night Trilogy ': [115, 115, 115, 115, 115, 115, 115, 81, 339, 109],
#  'Earthsea Cycle ': [183, 183, 183, 183, 478, 183, 183, 183, 478, 183],
#  'Song of the Lioness ': [274, 274, 274, 274, 274, 274, 274, 284, 384, 264],
#  'The Theban Plays ': [75,
#   75,
#   80,
#   75,
#   80,
#   75,
#   80,
#   259,
#   75,
#   80,
#   75,
#   80,
#   75,
#   80,
#   259],
#  'Stephanie Plum ': [320,
#   320,
#   320,
#   320,
#   320,
#   320,
#   320,
#   310,
#   230,
#   164,
#   384,
#   166,
#   371],
#  'Hainish Cycle ': [304,
#   304,
#   387,
#   304,
#   304,
#   387,
#   304,
#   304,
#   387,
#   304,
#   387,
#   362,
#   144,
#   160],
#  '1Q84 ': [925, 925, 925, 925, 925, 925, 925],
#  'The Farseer Trilogy ': [435, 435, 435, 435, 675, 435, 435, 435, 675],
#  'MaddAddam ': [389, 389, 389, 389, 431, 389, 389, 389, 431],
#  'Discworld ': [480,
#   480,
#   228,
#   400,
#   243,
#   432,
#   394,
#   376,
#   480,
#   228,
#   400,
#   243,
#   480,
#   228,
#   400,
#   243,
#   432,
#   394,
#   376,
#   352,
#   375,
#   277,
#   439,
#   228,
#   496,
#   424,
#   265,
#   464,
#   374,
#   480,
#   228,
#   400,
#   243,
#   480,
#   228,
#   400,
#   243,
#   432,
#   480,
#   228,
#   400,
#   243,
#   432,
#   394,
#   376,
#   352,
#   375,
#   277,
#   439,
#   228,
#   496,
#   424,
#   265,
#   464,
#   374,
#   411,
#   378,
#   336,
#   256,
#   396,
#   296,
#   377,
#   285,
#   325,
#   32],
#  'On the Seventh Day  ': [210, 210, 210, 210, 208, 210, 210, 210, 208],
#  'Gallagher Girls ': [284,
#   284,
#   236,
#   263,
#   284,
#   284,
#   236,
#   263,
#   265,
#   284,
#   284,
#   284,
#   236,
#   263,
#   265,
#   294,
#   296],
#  'Gentleman Bastard ': [752, 752, 752, 752, 752, 752, 752, 578, nan],
#  'Papillon ': [544, 544, 544, 544, 544, 544, 544],
#  'Sisterhood ': [294, 294, 294, 294, 294, 294, 294, 318, 1040],
#  'Philip Marlowe ': [231, 231, 231, 231, 379, 231, 231, 231, 379, 292, 265],
#  'Joseph Campbell and Power of Myth': [320, 320, 320, 320, 320, 320, 320],
#  'Dongeng Sepanjang Masa': [518, 518, 518, 518, 518, 518, 518],
#  'The Morganville Vampires ': [239,
#   239,
#   248,
#   239,
#   239,
#   248,
#   246,
#   245,
#   242,
#   241,
#   237,
#   239,
#   239,
#   239,
#   248,
#   246,
#   245,
#   242,
#   241,
#   237,
#   246,
#   335,
#   352,
#   368,
#   992,
#   440,
#   2279,
#   1944],
#  "No. 1 Ladies' Detective Agency ": [235, 235, 235, 235, 235, 235, 235, 960],
#  'Love Story ': [224, 224, 224, 224, 224, 224, 224],
#  'Captain Nemo ': [394, 394, 394, 394, 723, 394, 394, 394, 723],
#  'Shopaholic ': [368, 368, 368, 368, 368, 368, 368, nan],
#  'Dr. Laszlo Kreizler ': [498, 498, 498, 498, 498, 498, 498, 752],
#  'Simon Snow ': [522, 522, 522, 522, 522, 522, 522, 368],
#  'The Edge of Never ': [426, 426, 426, 426, 426, 426, 426, 465],
#  'Waverley Novels ': [541, 541, 541, 541, 541, 541, 541, 491],
#  'Odd Thomas ': [446, 446, 446, 446, 446, 446, 446, 352, 364],
#  'Freakonomics': [320, 320, 320, 320, 320, 320, 320],
#  'Princess Academy ': [314, 314, 314, 314, 314, 314, 314, 336],
#  'The Shadow Series ': [469, 469, 469, 469, 469, 469, 469],
#  'The Jungle Book ': [368, 368, 368, 368, 368, 368, 368, 142],
#  'St. Leibowitz ': [334, 334, 334, 334, 334, 334, 334],
#  'Green Town': [293,
#   293,
#   239,
#   293,
#   239,
#   293,
#   239,
#   293,
#   239,
#   293,
#   239,
#   293,
#   239,
#   211],
#  'Asher Lev ': [369, 369, 369, 369, 369, 369, 369],
#  'Red Rising Saga ': [382, 382, 382, 382, 382, 382, 430, 601],
#  "To All the Boys I've Loved Before ": [355, 355, 355, 337, 355, 355, 355],
#  'The Hate U Give ': [444, 444, 444, 444, 444, 444],
#  'Mary Poppins ': [209, 209, 209, 209, 209, 209],
#  'The Passage ': [766, 766, 766, 766, 766, 766],
#  'Forrest Gump ': [248, 248, 248, 248, 248, 248],
#  'The Sparrow ': [516, 516, 516, 516, 516, 516],
#  'Extraordinary Voyages ': [252, 252, 252, 252, 252, 252, 432, 95, 300],
#  "Gabriel's Inferno  ": [506, 386, 506, 506, 386, 506, 506, 506, 386, 477],
#  'Sevenwaters ': [554, 554, 554, 608, 554, 554, 554, 608, 432, 434],
#  'Illusions ': [144, 144, 144, 144, 144, 144],
#  'Kane & Abel ': [592, 592, 592, 592, 592, 592],
#  'Creekwood ': [303, 303, 303, 303, 303, 303],
#  'Anita Blake, Vampire Hunter ': [355,
#   355,
#   355,
#   320,
#   418,
#   355,
#   355,
#   355,
#   320,
#   418,
#   585,
#   368,
#   301,
#   644,
#   336,
#   392,
#   257,
#   297],
#  'Book of Ember  ': [288, 288, 288, 288, 288, 288],
#  'Crank ': [537, 537, 537, 537, 537, 537, 681],
#  'Jack Ryan ': [432, 432, 432, 432, 432, 432, 609],
#  'Bartimaeus ': [462, 462, 462, 501, 462, 462, 462, 501, 562],
#  'The Shadow and Bone Trilogy ': [358, 358, 358, 358, 358, 358, 435, 422, 30],
#  'Night World ': [729,
#   662,
#   729,
#   729,
#   662,
#   732,
#   729,
#   729,
#   729,
#   662,
#   732,
#   228,
#   228,
#   208,
#   240,
#   226,
#   227],
#  'Folktales': [256, 256, 256, 256, 256, 256, 304],
#  'Bryson and Katz ': [397, 397, 397, 397, 397, 397, 254],
#  'Will Grayson, Will Grayson ': [310, 310, 310, 310, 310, 310, 208],
#  'Ferdinand Bardamu ': [453, 453, 453, 453, 453, 453],
#  'Thoughtless ': [530, 487, 530, 530, 487, 546, 530, 530, 530, 487, 546],
#  'Fablehaven ': [351, 351, 351, 456, 351, 351, 351, 456, 535, 477, 593, 1328],
#  'Contours of the Heart ': [336, 336, 336, 336, 336, 336, 361],
#  'The Vampire Diaries ': [492, 520, 492, 492, 520, 492, 492, 492, 520, 272],
#  'Logans ': [288, 288, 288, 288, 288, 288],
#  'Otherworld ': [436, 436, 436, 436, 436, 436, 371, 528],
#  'Hunter Legends ': [337, 337, 337, 337, 337, 337],
#  '5 Love Languages': [209, 209, 209, 209, 209, 209],
#  'Wings ': [290, 290, 290, 359, 290, 290, 290, 359, 375],
#  'Every Day ': [322, 322, 322, 322, 322, 322],
#  'Warriors ': [288, 288, 288, 288, 288, 288, 315],
#  'Sarah Agnes Prine ': [384, 384, 384, 384, 384, 384, 320],
#  'The Man Without Qualities ': [1774, 1774, 1774, 1774, 1774, 1774, 1072],
#  "The Tiger's Curse Series ": [403,
#   560,
#   403,
#   403,
#   560,
#   479,
#   403,
#   403,
#   403,
#   560,
#   479,
#   464],
#  'Redwall ': [352, 352, 352, 352, 352, 352, 408, 387, nan],
#  "Ranger's Apprentice ": [249,
#   249,
#   249,
#   262,
#   249,
#   249,
#   249,
#   262,
#   294,
#   304,
#   266,
#   848],
#  'Hex Hall ': [323, 323, 323, 359, 327, 323, 323, 323, 359, 327],
#  'The Border Trilogy ': [302, 302, 302, 302, 302, 302, 426],
#  'Unearthly ': [435, 435, 435, 435, 435, 4, 94],
#  'The Hollows ': [416,
#   416,
#   501,
#   416,
#   416,
#   416,
#   501,
#   453,
#   510,
#   504,
#   456,
#   312,
#   155],
#  'Call Me By Your Name  ': [248, 248, 248, 248, 248, 260],
#  'Kendra Chronicles ': [304, 304, 304, 304, 304],
#  'Blue Bloods ': [302, 302, 307, 369, 264, 302, 302, 302, 307, 369, 264, 227],
#  'The Devil Wears Prada ': [432, 432, 432, 432, 432, 343],
#  'An Ember in the Ashes ': [446, 446, 446, 446, 446, 400],
#  'French Trilogy ': [483, 483, 483, 483, 401],
#  "The Pilgrim's Progress ": [324, 324, 324, 324],
#  'The Leatherstocking Tales ': [410, 410, 410, 410],
#  'Across the Universe ': [399, 399, 386, 399, 399, 386, 369],
#  "Brian's Saga ": [208, 208, 208, 208],
#  'Crossroads ': [266, 266, 340, 266, 266, 340],
#  'Nightshade ': [452, 452, 452, 452, 406, 390],
#  'The Dresden Files ': [355, 355, 355, 355, 517, 446, 401, 438, 378, 418, 1],
#  'Dirk Gently ': [306, 306, 307, 306, 306, 307],
#  'The Riftwar Saga ': [681, 681, 681, 681, nan],
#  'VanWest ': [195, 200, 195, 200, 195, 195, 200],
#  'To Live ': [320, 320, 320, 320],
#  'The Mysterious Benedict Society ': [497, 497, 497, 497, 440, 11, 1376],
#  'Evernight ': [327, 327, 329, 327, 327, 329, 339],
#  'On Dublin Street ': [372, 372, 372, 372, 36, 370, 111, 334],
#  'Alpha & Omega ': [294, 294, 294, 294, 61, 308, 324],
#  'Shades of Magic ': [400, 400, 624, 512, 400, 400, 624, 512, 602],
#  'The Henry Family ': [896, 896, 1042, 896, 896, 1042],
#  'Tropic ': [318, 318, 318, 318, 348],
#  'Darkness ': [376, 376, 376, 376, 684],
#  'Practical Magic ': [286, 286, 286, 286, 369],
#  'Night Angel ': [645, 645, 689, 636, 645, 645, 689, 636],
#  'Die Danziger Trilogie ': [580, 580, 580, 580, 191],
#  'Covenant ': [281, 281, 329, 330, 281, 281, 329, 330, 297, 343],
#  'Trylle ': [216, 216, 324, 326, 216, 216, 324, 326],
#  'The Dark Artifices ': [698, 698, 698, 698, 701],
#  "Phèdre's Trilogy ": [1015, 1015, 1015, 1015],
#  'Burgdorf Cycle ': [525, 525, 525, 525],
#  'Persepolis ': [341, 341, 153, 341, 341, 153],
#  'Grim Reaper ': [387, 387, 387, 387],
#  'Jaws ': [320, 320, 320, 320],
#  'Les Rougon-Macquart ': [592, 592, 592, 592, 480, 660, 464],
#  'Starcrossed ': [487, 487, 487, 487, 487],
#  '源氏物語   ': [1182, 1182, 1182, 1182],
#  'Harriet the Spy ': [300, 300, 300, 224],
#  'Rosemary Beach ': [300, 300, 300, 193, 256, 234, 273],
#  'Mary Russell and Sherlock Holmes ': [341, 341, 341, 352, 320, 488],
#  'The First Law ': [515, 515, 515, 536, 1600],
#  'Batman: The Dark Knight Returns ': [197, 197, 197],
#  'Pretty Little Liars ': [286, 286, 286, 305, 307, 1500, 290, 338, 352],
#  'Triffids ': [228, 228, 228],
#  'Under the Never Sky ': [374, 374, 374, 341, 1304],
#  'The Secrets of the Immortal Nicholas Flamel ': [390,
#   390,
#   390,
#   502,
#   12,
#   67,
#   1500],
#  'Celestine Prophecy ': [247, 247, 247, 256],
#  'Gormenghast ': [1173, 1173, 1173, 396, 252],
#  'Blood of Eden ': [485, 485, 485],
#  'Halo ': [485, 485, 485, 200, 352],
#  'Sweet ': [447, 447, 447, 375, 272, 484],
#  'George Smiley ': [224, 224, 381, 224, 381, 397, 160],
#  'Waverley Family ': [304, 304, 304, 296],
#  'Kate Daniels ': [261,
#   261,
#   349,
#   310,
#   261,
#   261,
#   349,
#   310,
#   261,
#   308,
#   342,
#   381,
#   327],
#  'Nonie Broussard Ghost Tracker': [304, 304, 304],
#  'Wait for You ': [332, 332, 332, 365],
#  'The Princess Diaries ': [283, 283, 283, 96, 259, 306, 238, nan, 50],
#  'The Devil ': [469, 469, 469],
#  'The Century Trilogy ': [985, 985, 940, 985, 940],
#  'In Death ': [306,
#   306,
#   306,
#   440,
#   345,
#   14,
#   364,
#   389,
#   388,
#   347,
#   355,
#   373,
#   360,
#   354,
#   339,
#   355,
#   327],
#  'Alexander': [32, 32, 32],
#  'Gilead': [247, 247, 247],
#  'The Illuminae Files ': [608, 608, 608],
#  'Darcy & Rachel ': [322, 322, 322],
#  'Shadow Falls ': [398, 398, 398, 2119, 32],
#  'Mercy Thompson ': [287, 287, 292, 300, 342, 287, 292, 300, 342, 342, 341],
#  'Elantris ': [638, 638, 638],
#  'Old Yeller ': [132, 132, 132],
#  'New Crobuzon ': [623, 623, 623],
#  'Damar ': [256, 256, 256, 240],
#  'Matteo Alacran ': [380, 380, 380],
#  'Three Men ': [185, 185, 185, 400],
#  'The Folk of the Air ': [370, 370, 336, 370, 336, 300],
#  'Cheaper by the Dozen ': [292, 292, 292],
#  'If You Give...': [40, 40, 40, 40],
#  'Diary of a Wimpy Kid ': [224, 224, 224, 224, 217, 224, 912, 224, 224],
#  'The Hundred-Year-Old Man ': [396, 396, 396, 396],
#  'Shadow Children ': [153],
#  'Ancient Egypt ': [664, 664, 664],
#  'The Belgariad ': [304, 304, 304],
#  "Old Man's War ": [332, 332, 332, 347, 320],
#  'Pushing the Limits ': [392, 392, 392],
#  'Demon Cycle ': [416, 416, 416, 681],
#  'Impulse ': [666, 666, 666],
#  'Burned ': [431, 431, 431, 543],
#  'Villains  ': [366, 366, 366],
#  'Need ': [306, 306, 306, 272],
#  'Arthurian Saga ': [494, 494, 494, 928, 475, 513],
#  'Summer ': [276, 276, 276, 291, 295, 721],
#  'Who Moved My Cheese? ': [96, 96, 96],
#  'The Forever War ': [278, 278, 278],
#  'Tracy Whitney ': [501, 501, 501, 400],
#  'Real ': [293, 293, 293],
#  'Kissed by an Angel ': [690, 690, 690, 288, 225, 235],
#  'The Original Shannara Trilogy ': [726, 726, 726, 489],
#  'Last Survivors ': [337, 337, 337],
#  'Manufactured Identity ': [305, 305, 314, 410, 305, 314, 410],
#  'A Song of Ice and Fire 1-in-2 ': [639, 639, 663, 639, 663],
#  'Jack Reacher ': [424, 424, 424, 441, 512, 15, 432, 353, 400, 416],
#  'Mark of the Lion ': [520, 520, 520, 461],
#  'Skulduggery Pleasant ': [392, 392, 392, 480, 128],
#  'Island of the Blue Dolphins ': [194, 194, 194, 194],
#  'Quiet': [333, 333],
#  'Rama ': [243, 243, 480, 593],
#  'Love Me with Lies ': [278, 278, 273],
#  "The Good Ol' Boys ": [397, 397],
#  'A Bridge of Leaves ': [1474, 1474],
#  'Heaven is For Real': [162, 162],
#  'Cloudy with a Chance of Meatballs ': [32, 32],
#  'New York Trilogy ': [308, 308],
#  'The Sandman ': [233, 233],
#  'The Ascendance Series ': [342, 342],
#  'Wells klassiker ': [192, 192],
#  'Noughts and Crosses ': [479, 479, 364, 528, 480],
#  'Cormoran Strike ': [456, 456],
#  'Tomorrow ': [276, 276, 261, 243, 264, 270, 259],
#  'Cocktail ': [384, 384],
#  'The Boy Who Sneaks in My Bedroom Window ': [242, 242],
#  'Thomas Cromwell ': [604, 604, 672],
#  'The Black Magician Trilogy ': [644, 467, 577, 644, 467, 577],
#  'Revenants ': [341, 341, 405],
#  'Feynman ': [400, 400, 256],
#  'Keeper of the Lost Cities ': [496, 496, 624, 576, 672, 688, 1744, 764, 11],
#  'The Witcher ': [360, 360],
#  'Rats of NIMH ': [240, 240],
#  'Alex Cross ': [481, 449, 481, 449, 403, 391, 400, 416],
#  'The Chronicles of Amber ': [1258, 1258, 189, 223, 900, 338, 192],
#  'Hometown ': [321, 321],
#  'The Dark Duet ': [276, 505, 276, 505],
#  'Complete Nathan Zuckerman ': [432, 432, 334],
#  'Guild Hunter ': [339, 339, 323, 337, 357, 368],
#  'Talion ': [432, 432],
#  'Don Tillman ': [295, 295],
#  'Warm Bodies ': [256, 256],
#  'Alexandria Quartet ': [884, 884, 253, 280, 320, 288],
#  'The Game ': [489, 489],
#  'North and South ': [812, 812, 781],
#  'On the Island ': [368, 368],
#  'Georgina Kincaid ': [343, 343, 314],
#  'Long Walk to Freedom ': [656, 656],
#  'The Land of Stories ': [438, 438, 517],
#  'Oxford Time Travel ': [578, 512, 578, 512],
#  'Paranormalcy ': [335, 335, 336],
#  'Caraval ': [432, 432],
#  'Lost Kingdoms of Karibu ': [276, 276],
#  'Rizzoli & Isles ': [416, 416, 349],
#  'Seven Realms ': [506, 506, 586],
#  'The Collected Works of W.B. Yeats ': [544, 544, 305],
#  'The Eight ': [598, 598],
#  'Firelight ': [323, 323],
#  'Lincoln Rhyme ': [528, 528, 414],
#  'Illuminatus! ': [805, 805],
#  'Firefly Lane ': [479, 479],
#  'Sugar Mountain ': [nan, 289, nan, 289],
#  'Lords of the Underworld ': [379, 379, 406, 410, 66, 489, 504, 65],
#  'Hamilton High ': [280, 280],
#  'A Distant Mirror: The Calamitous 14th Century': [677, 677],
#  'Dragonriders of Pern ': [299, 299, 864],
#  'Fall Away ': [333, 333, 366, 429],
#  'Arc of a Scythe ': [435, 435],
#  'Parasol Protectorate ': [357, 357],
#  'Brathius History ': [544, 544],
#  'Abhorsen ': [464, 358, 464, 358, 368],
#  'Wars of the Roses ': [414, 414, 398],
#  'Mercy ': [nan, nan, 233],
#  'This Man ': [448, 501, 448, 501, 452, 480],
#  'The Chemical Garden ': [358, 358],
#  'The Forest of Hands and Teeth ': [310, 310],
#  'Rich Dad ': [195, 195, 376, 384, 383],
#  'The Black Jewels ': [1204, 1204],
#  'Beautiful Bastard ': [320, 320, 160],
#  'Bosnian Trilogy ': [314, 314, 437],
#  'The Young Elites ': [355, 355, 398],
#  'Silo ': [509, 509],
#  'Breathing ': [377, 377, 962],
#  'Midnight Breed ': [402, 402, 369, 387],
#  'Ringworld ': [288, 288],
#  'Cole Family Trilogy ': [714, 714, 652],
#  "The Queen's Thief ": [387, 280, 387, 280],
#  'Auschwitz Trilogy ': [187, 187],
#  'Death Note ': [195, 195, 188],
#  'Code Name Verity ': [452, 452],
#  'Just One Day ': [369, 369, 40],
#  'Chicagoland Vampires ': [341, 341, 355, 352, 352, 350, 350, 350],
#  "Moloka'i ": [405, 405],
#  'The Diviners ': [578, 578, 613],
#  'Sarah, Plain and Tall ': [64, 64],
#  'The Magicians ': [402, 402, 1203],
#  'After ': [582, 582, 348],
#  'Khalifa Brothers ': [224, 224],
#  'The Vampire Diaries: The Return ': [586, 599, 586, 599, 567],
#  'The Testing ': [325, 325, 304, 310],
#  'Women at Work ': [362, 362],
#  'The Remnant Chronicles ': [492, 492],
#  'Sinuhe egyptiläinen ': [514, 514],
#  'Dust Lands ': [459, 459, 424],
#  'Inspector Alan Grant ': [206, 206],
#  'Splintered ': [371, 371, 288, 40],
#  'Leviathan ': [440, 440, 954],
#  'Magnus Chase and the Gods of Asgard ': [499, 499, 528],
#  'DCYE ': [326, 287, 326, 287],
#  'Zamonien ': [461, 461, 704],
#  "The Winner's Trilogy ": [355, 355, 416],
#  'The Wrath and the Dawn ': [404, 404],
#  'Existence  ': [161, 161, 94],
#  'Lumatere Chronicles ': [416, 416, 593],
#  'The Mediator ': [312, 287, 312, 287, 402, 432],
#  'Eon ': [531, 531, 637],
#  'The Forbidden Game ': [750, 750],
#  'Warbreaker ': [688, 688],
#  'Nevermore ': [543, 543, 429, 448],
#  'Дозоры ': [455, 455, 370, 1531],
#  'The Liveship Traders ': [880, 880, 789, 1861],
#  'Psy-Changeling ': [334, 334, 483, 321, 422, 348, 478],
#  'Daddy-Long-Legs ': [249, 249, 350],
#  'The Sight ': [486, 486],
#  'The Coincidence ': [283, 283, 200, 294],
#  'Heist Society ': [287, 287],
#  'The Horn King ': [242, 242, 278],
#  'Leo Demidov ': [509, 509],
#  'Tales of the City ': [272, 272],
#  'His Fair Assassin ': [549, 549],
#  'The Tattooist of Auschwitz ': [262, 262, 277],
#  'Avalon High ': [288, 288],
#  'Tangled ': [254, 254, 256, 272],
#  'Memory, Sorrow, and Thorn ': [672, 672, 815, 815],
#  'Fruits Basket ': [216,
#   216,
#   192,
#   196,
#   202,
#   208,
#   196,
#   194,
#   194,
#   196,
#   202,
#   198,
#   192,
#   196,
#   200,
#   202],
#  'Significance Series  ': [387, 387, 75],
#  'Immortals After Dark ': [360, 360, 430, 356, 529, 163],
#  'Le deuxième sexe ': [746, 746],
#  'Strange the Dreamer ': [544, 544, 522],
#  'Species Intervention ': [173, 173, 190],
#  'Maybe ': [385, 385],
#  'The Tea Rose ': [675, 675],
#  'Horton the Elephant': [64, 64, 64],
#  'Ramses the Damned ': [480, 480],
#  'Lord Peter Wimsey ': [501, 501, 212, 240, 356, 409],
#  'The Chronicles of Prydain ': [190, 190, 174],
#  'One Thousand White Women ': [434, 434],
#  'Dream Cycle ': [362, 362],
#  'The Books of Pellinor ': [492, 492],
#  'Ripley ': [320, 320],
#  'The Winters Family Saga ': [326, 326],
#  'Wake ': [210, 210],
#  'The Gulag Archipelago 1918-1956 ': [472, 472, 712],
#  'Dark Visions ': [732, 732, 212],
#  'Night Huntress World ': [371, 371, 361],
#  'Leaving Paradise ': [303, 303],
#  'Seraphina ': [499, 499],
#  'Andromeda ': [327, 327],
#  'Incarceron ': [458, 458],
#  'The Baroque Cycle ': [927, 927, 815],
#  'Batman: One-Shots': [50, 50, 144, 42],
#  "L'amica geniale ": [331, 331, 331],
#  'Montgomery/Taggert Publication order  ': [464, 464, 320, 392, 330],
#  'Cirque du Freak ': [272, 272, 592, 489],
#  'Alex Rider ': [256, 256, 385, 405],
#  'Mateguas Island ': [380, 380],
#  'Pollyanna ': [304, 304],
#  'The Body Finder ': [327, 327],
#  'The Coming Storm ': [310, 310],
#  'Cannie Shapiro ': [376, 376],
#  'White Rabbit Chronicles ': [404, 404],
#  'Charley Davidson ': [310, 310, 322],
#  'Aubrey & Maturin ': [464, 464, 350, 348, 262, 282],
#  'Flavia de Luce  ': [386, 386, 364, 293, 378, 310, 392],
#  'Daughter of the Lioness ': [448, 448, 496, 590],
#  'Anna ': [316, 316],
#  'Jeremy Marsh & Lexie Darnell ': [204, 204, 465],
#  'Tracy Crosswhite ': [416, 416, 426, 362],
#  'Legacy of Orïsha ': [544, 544, 404],
#  'The Fray Theory ': [350, 350],
#  'The Rat ': [353, 393, 353, 130, 215],
#  'Padre Anthony Fowler ': [368, 368, 386],
#  'The Tawny Man ': [914, 914, 661],
#  'Montague Siblings ': [513, 513],
#  'Angelfire ': [453, 453, 469],
#  'Tales of the Otori ': [305, 305, 560],
#  'The Wise Society ': [312, 312],
#  'Time ': [399, 399, 304],
#  'The Broken Earth ': [468, 468],
#  'Pha Yul ': [352, 352],
#  'The Saga of Arturo Bandini ': [165, 165, 167],
#  'The Lymond Chronicles ': [543, 543, 432],
#  'Starters ': [352],
#  'The Bone Season ': [466],
#  'The Grey Wolves ': [230],
#  'Strange Angels ': [293, 596],
#  'Hate List': [405],
#  'Culture ': [293, 188, 496, 593, 352],
#  'The Drenai Saga ': [345, 589, 291, 306],
#  'The Space Trilogy ': [288],
#  'The Forsyte Chronicles ': [872],
#  'Falling Kingdoms ': [412],
#  'The Civil War ': [2934, 856, 976],
#  'From Hell ': [576],
#  'Septimus Heap ': [564, 628, 641, 2230, 596],
#  'The Dark Elf Trilogy ': [808],
#  'Dragonlance: Chronicles ': [444],
#  'Wildwood ': [407, 432],
#  'Malazan Book of the Fallen ': [925, 1280],
#  'Captive Prince ': [216, 240, 385, 352, 404],
#  'Peter and the Starcatchers ': [452, 438, 482, 528],
#  'Todd Family ': [531],
#  'Lightbringer ': [629, 704],
#  'Westmoreland Saga ': [708],
#  'Modern Faerie Tales ': [332],
#  'Shiva Trilogy ': [436, 398],
#  "Rosemary's Baby ": [308],
#  'The Indian in the Cupboard ': [192],
#  'Dexter ': [288, 292, 350, 304],
#  'Civilizations Rise and Fall ': [425],
#  "Raven's Shadow ": [591],
#  'New Tales of the Vampires ': [383],
#  'Dublin Murder Squad ': [429, 466, 453, 400, 450],
#  'The Trials of Apollo ': [375, nan, 416],
#  'John Dies at the End ': [362, 406],
#  'Goddess Test ': [293, 303],
#  'Secret ': [364, 352],
#  'Stillhouse Lake ': [301],
#  'The Others ': [433, 399, 397],
#  'Harold ': [64],
#  'Dorothy Must Die ': [452, 277, 392],
#  'Kay Scarpetta ': [342, 351, 466, 383, 440],
#  'The Nevernight Chronicle ': [429],
#  'Winternight Trilogy ': [323],
#  'Fullmetal Alchemist ': [192, 192, 192, 192, 192],
#  'World of the Five Gods Publication ': [490],
#  'The Reckoners ': [386, 417, 416],
#  'Kristin Lavransdatter ': [1144],
#  'Angel ': [507, 496],
#  'The Dark Elements ': [400, 105, 448],
#  'I nostri antenati ': [217],
#  'La sonrisa vertical ': [103],
#  'All for the Game ': [237, 556],
#  'Codex Alera ': [504],
#  'Underland Chronicles ': [326],
#  'The Analyst ': [491],
#  'Bird Box ': [262],
#  'Narratives of Empire ': [430, 672],
#  'The Autobiographies ': [158, 400],
#  'The Dark Is Rising ': [1148, 272, 165, 147, 274],
#  'The Cay ': [156, 145],
#  'Newsflesh ': [599],
#  'The Violet Eden Chapters ': [382],
#  'The Missing ': [320, 352],
#  'Protector of the Small ': [240, 400, 791],
#  'Undead ': [255, 271, 272, 294, 288, 286, 272, 285],
#  'Marked Men ': [369, 416, 302, 387],
#  'The Bane Chronicles ': [507, 61, 15, 61, 64],
#  'Earthseed ': [345],
#  'Mountain ': [192],
#  'The Warlord Chronicles ': [433],
#  'The Last Vampire ': [594, 176, 394],
#  'Green Rider ': [471, 784],
#  'Beartown ': [432],
#  'The Deptford Trilogy ': [252],
#  'Off-Campus ': [342, 296],
#  'The Chronicles of Vladimir Tod ': [182, 1120],
#  'Little Nutbrown Hare': [20],
#  'The Last Kingdom ': [351],
#  'Love ': [668],
#  'Mercy Kilpatrick ': [322, 353],
#  'Gabriel Allon ': [576, 501, 437, 432, 448, 484, 416, 496],
#  'Soul Screamers ': [279, 64, 570, 56],
#  'Musashi ': [970],
#  'The Strigoi ': [377],
#  'The Greek Isles Series ': [194, 224],
#  'The Secret Life of Amy Bensen ': [384, 218],
#  'Partials Sequence ': [468],
#  'Virals ': [454, nan],
#  'Mickey Haller ': [528, 389, 422],
#  'The Way, With The Enchanted Neighborhood': [176],
#  'The Broken Empire ': [373],
#  'One of Us Is Lying ': [360, 377],
#  'The Archived ': [327],
#  'Perfect ': [280],
#  'Demonica ': [389, 44],
#  'Chronicles of Nick ': [464, 451],
#  'The Black Stallion ': [275, 212],
#  'Taking Chances ': [432, 400],
#  'Little Blue Envelopes ': [322],
#  'Oresteia ': [335],
#  'Slains ': [527, 484],
#  'Neighbor from Hell  ': [330, 266],
#  'Saga Collected Editions ': [176, 160, 152, 152],
#  'Dark Swan ': [361, 400],
#  'Temeraire ': [356, 365, 398, 352, 274, 325],
#  'Razorland  ': [259],
#  'Skinjacker ': [320, 512],
#  'The 39 Clues ': [220],
#  "Mr. Penumbra's 24-Hour Bookstore ": [288],
#  'The Serve ': [286, 187],
#  'Sjálfstætt fólk ': [482],
#  'The Change ': [209, nan, nan],
#  'Pride and Prejudice and Zombies ': [320],
#  'Jonathan Harkon Adventures ': [123],
#  'The School for Good and Evil ': [544],
#  'The Hollow ': [544],
#  'МЕТРО ': [458],
#  'The Absolute Sandman ': [612],
#  'The Girl With All the Gifts ': [461, 369],
#  'The Legend of Drizzt ': [343, 349],
#  'Zachary Blake Legal Thriller ': [348, 496],
#  'Never Never ': [300],
#  'Pop-up Classics': [262],
#  'Rabbit Angstrom ': [337, 1520, 440, 700, 384],
#  'Same Kind of Different as Me ': [240],
#  'War Horse ': [165],
#  'Slated ': [439],
#  'Nanny ': [306],
#  'Crashing Down to Earth Series ': [nan],
#  'Olive Kitteridge ': [270],
#  'Raised by Wolves ': [432],
#  'Jeeves ': [256, 273, 272, 224, 240, 205, 206, 208],
#  'Harry Bosch ': [482, nan, 454, 416, 417, 416, 448],
#  'Dragon Slippers ': [324],
#  'Starbound ': [389, 394],
#  'The Two Princesses of Bamarre ': [304, 416],
#  'Night School ': [454, 375, 393],
#  'First Law World ': [534, 451],
#  'The Master of Perceptions ': [326],
#  'Shapes of Autumn ': [389],
#  'John Clark ': [912, 1137],
#  'Aztec ': [754],
#  'Morgan Dane ': [329],
#  'Star Wars: The Thrawn Trilogy ': [434],
#  'Valdemar: The Last Herald-Mage ': [349],
#  'The Riyria Revelations ': [649, 620, 317, 331],
#  'Fallen Crest High ': [375, 402],
#  'Valdemar: Heralds of Valdemar ': [320, 726],
#  'Professor Challenger ': [272],
#  'Angels in America ': [119, 158],
#  'Sempre ': [518],
#  'Smile ': [224],
#  'Shades of Grey ': [400],
#  'Vorkosigan Saga Publication Order ': [372, 560, 367, 311, 302, 345, 880],
#  'Abarat ': [393],
#  'Midnight ': [315, 315, 462, 301, 220, 328],
#  'James Bond Original Series ': [192, 326],
#  'The Golem and the Jinni ': [486],
#  'Lake Haven ': [300],
#  'Emily ': [339, 325],
#  'Harry Potter and the Methods of Rationality': [2184],
#  'Chronicles of Ancient Darkness ': [295],
#  'Driven ': [327, 400, 380, 140],
#  'The Princess Trilogy ': [286, 826],
#  'The One and Only Ivan ': [307],
#  'The Woman in Black ': [138],
#  'Shanghai Girls ': [309],
#  'A Forgotten Gods Tale ': [424],
#  'The Strain Trilogy ': [403, 308],
#  'Wool  ': [58],
#  'First Comes Love ': [224],
#  'Pendragon ': [375],
#  'Shifters ': [618],
#  'The Last Apprentice / Wardstone Chronicles ': [344, 432, 400],
#  'Healer ': [390],
#  'Night Prince ': [373],
#  'RAW Family ': [359],
#  'The World As Myth ': [589, 388],
#  'The World of Beatrix Potter: Peter Rabbit': [72, 58, 57, 58, 58],
#  'Ten Tiny Breaths ': [262],
#  'Bill Hodges Trilogy ': [437, 432],
#  'The Half Bad Trilogy ': [394],
#  'Flat-Out Love ': [355, 338],
#  'Mathias Drvar ': [230],
#  'Psycho ': [208],
#  'Incarnations of Immortality ': [325, 405, 314, 372],
#  'Shades of London ': [372, 376],
#  'Arkady Renko ': [433, 473],
#  'Dash & Lily ': [260],
#  'Jessica ': [351, 309, 90],
#  'Pendergast ': [629, 468, 464, 457, 403, 368],
#  'Wilderness ': [876, 628],
#  'The Lover ': [117],
#  'Calvin and Hobbes ': [256, 128, 128, 176, 176, 126],
#  'High Places  ': [317],
#  'Stalking Jack the Ripper ': [327, 453],
#  'Sydney Jones ': [210],
#  'Takeshi Kovacs ': [544],
#  'The Chronicles of Thomas Covenant the Unbeliever ': [480, 480, 527],
#  'The Declaration ': [320, 323, 272],
#  'Barsoom ': [186, 6, 190, 0, 617],
#  'Batman 1940-2011 ': [144, 320, 144],
#  'The Hellfire Chronicles ': [266],
#  'Fifty Shades as Told by Christian ': [576, 546],
#  'Moties ': [596, 413],
#  'Everville ': [242],
#  'The King Trilogy ': [nan, nan],
#  'The Walking Dead Collected Editions ': [144,
#   136,
#   136,
#   148,
#   136,
#   136,
#   144,
#   136],
#  'My Blood Approves ': [278, 101],
#  'Fantastic Beasts: The Original Screenplay ': [280],
#  'You ': [422],
#  'Y: The Last Man ': [130, 168],
#  'Second Opportunities ': [709, 485],
#  'Masters of Rome ': [1076, 928, 1110, 567],
#  'Undeniable  ': [219, 306],
#  'Fool ': [311],
#  'Daemon ': [632],
#  'Tarzan ': [324],
#  'The Boxcar Children ': [160, 672],
#  'The Last Riders ': [229, 277, 457],
#  'Innkeeper Chronicles ': [225, 237],
#  'Beauty ': [292],
#  'White Knight Dom Academy ': [117, 122],
#  'The Magpies ': [400],
#  'Lock In ': [336],
#  'The Gadfly ': [384],
#  'The Arcana Chronicles ': [336, 280, 174, 318],
#  'Warriors: Omen of the Stars ': [352, 352],
#  'Moonlight Bay ': [12],
#  'Paradise ': [367, 374],
#  'Zion Covenant ': [400, 448, 544, 282, 296, 322],
#  'In the Company of Shadows ': [1015, 334, 344],
#  'The Legends of the First Empire ': [432],
#  'The Gender Game ': [418],
#  'Blue is for Nightmares ': [320],
#  'Lovely★Complex ': [180],
#  "Rapunzel's Revenge ": [144, 144],
#  'Gods & Monsters ': [285],
#  'Frames: The Freddie Montgomery Trilogy ': [220],
#  'The League: Nemesis Rising ': [418, 518, 540, 736, 564],
#  'Uninvited ': [384],
#  'The War That Saved My Life ': [387, 296],
#  'Scott Pilgrim ': [205, 200, 178, 192, 245],
#  ' Johnny Merrimon ': [373],
#  'Twilight: The Graphic Novel ': [240, 160],
#  'Fallen Angels ': [454, 388],
#  'The Clann ': [416],
#  'Avatar: The Last Airbender Books': [184, 90, 96, 86, 96],
#  'Blud ': [395],
#  'The Bad Boys ': [289],
#  'Lorien Legacies: The Lost Files ': [108,
#   416,
#   144,
#   144,
#   97,
#   144,
#   101,
#   100,
#   75],
#  'Harmony ': [320, 306],
#  'The Chanters of Tremaris ': [320],
#  'Sid Halley ': [304],
#  'Archie Sheridan & Gretchen Lowell ': [325],
#  'Mackenzie Family ': [490, 788, 248, 250, 496, 256],
#  'Elli Friedmann ': [234],
#  'The Homelanders ': [346, 345],
#  'Cassandra Palmer ': [419, 357],
#  'The Candymakers ': [453],
#  'Seeds of America ': [316],
#  'All my friends... ': [96],
#  'Adrian Mole ': [163, 182, 400],
#  'Helen Grace ': [395],
#  'Tales from the Shadowhunter Academy ': [96, 40, 91, 98],
#  "The Conqueror's Saga ": [416],
#  'Young Wizards ': [758, 552, 384, 432, 372],
#  'Lost Love ': [333],
#  'Temperance Brennan ': [448, 315, 383],
#  'Harper Connelly ': [295, 320],
#  'Pride ': [307, 379, 346, 391],
#  'Sacred Games': [916],
#  'The Saga of Larten Crepsley ': [261, 272],
#  'Shattered Hearts ': [232, 322, 349],
#  'Knights Rebels MC ': [301],
#  'Memories of the Eagle and the Jaguar ': [304, 464],
#  'Will Trent ': [379, 448, 398, 461, 496],
#  'The Last Picture Show ': [280],
#  'Queen of Camelot ': [623],
#  'Shadowmarch ': [796, 672, 766, 656],
#  'Sharpe ': [288, 256, 288, 385, 304],
#  'Dirk Pitt ': [345, 552, 602, 391, 537],
#  'When the Wind Blows ': [384],
#  'Chief Inspector Armand Gamache ': [371, 322, 390, 372, 391],
#  'Dragon Age ': [444, 416],
#  'Vernon Sullivan ': [177],
#  'Batman 2011 ': [176, 176],
#  'Deadly Beauties ': [270],
#  'Quincy & Rainie ': [451, 389, 432],
#  'Ruin ': [107, 357],
#  'Walker Family ': [352],
#  'In the Garden ': [303, 351],
#  'Sally Lockhart ': [416, 304],
#  'Leven Thumps ': [406, 407, 400],
#  'Charlie Parker ': [503, 436],
#  'Goosebumps ': [144, 134, 144, 144, 144, 114, 117],
#  'The Secret Series ': [164, 294],
#  'Birthmarked ': [293],
#  'Ruining ': [215, 149],
#  'Von Trotta Family': [363],
#  'Spatterjay ': [432],
#  'The Expanse ': [581, 595, 539, 538, 608],
#  'The Circle Opens ': [357, 264],
#  'Born In Trilogy ': [416, 371, 0],
#  'Detective D.D. Warren ': [388, 451, 373],
#  'Night Watch ': [281, 338, 323, 310, 275],
#  'Dark ': [560, 382, 352, 432, 326, 385],
#  'The Bounty Trilogy ': [400],
#  'Batman: Dark Victory ': [391],
#  'October Daye ': [354, 354, 346, 358, 357],
#  'I-Team ': [335, 361, 405, 375, 374],
#  'Enola Holmes ': [183, 170, 216, 234, 166],
#  'Mitch Rapp ': [448, 385],
#  'Hap and Leonard ': [nan],
#  'Tuesday McGillycuddy ': [288],
#  "Guardians of Ga'Hoole ": [202, 221, 203, 198, 232, 207, 242],
#  'Homecoming Saga ': [352, 430, 370, 351],
#  'Matthew Corbett ': [645, 816],
#  "Bad Girls Don't Die ": [442],
#  'Emperor ': [531, 409],
#  'Sigma Force ': [464, 608, 688, 480, 448],
#  'Scorched ': [352],
#  'Ladies of the Manor ': [439],
#  'The Karla Trilogy ': [952],
#  'The Rainbow Fairy Books': [390],
#  'Bones of Faerie ': [247],
#  'Sunrise ': [323, 315, 301, 350],
#  'Winnetou ': [650, 787],
#  'Chronicles of Brother Cadfael ': [197],
#  'Tales From The Sinister City ': [297],
#  'Bridgertons ': [372, 368, 384],
#  'The Hardy Boys ': [214, 192, 228],
#  'Possession ': [416],
#  'Law of the Lycans ': [479, 462],
#  'The 39 Clues: Cahills vs. Vespers ': [222, 192, 192, 190],
#  'Coulters Historical ': [410, 417, 421],
#  'Titan ': [335, 268],
#  'Mortal Engines Quartet ': [316, 533],
#  'The Chronicles of Alice ': [291],
#  'Atlee Pine ': [405],
#  'D.I. Lottie Parker ': [424],
#  "Stephen Fry's Great Mythology  ": [416],
#  'Knuffle Bunny ': [40],
#  'Warriors Manga: Tigerstar & Sasha ': [82, 86, 86],
#  'Voices of Dragons ': [309],
#  'Cat Royal Adventures ': [421, 366],
#  'Kingdom Keepers ': [544, 378],
#  'Kinship and Courage ': [416],
#  'The Riyria Chronicles ': [347],
#  'DI Kim Stone ': [390, 384, 387, 380],
#  'Extinction ': [219],
#  'Riley Jenson Guardian ': [356, 355, 371, 346, 356, 355, 352],
#  'Restoration ': [381, 291, 355, 411, 371],
#  'Confessions of Georgia Nicolson ': [320, 214, 271, 276],
#  'The Familiars ': [360],
#  'Corpus ': [384],
#  'Kendrick/Coulter/Harrigan ': [420, 421, 412, 345, 408, 412, 419],
#  'Disruption ': [400, 437],
#  "Thieves' World Novels": [238],
#  'Tintin ': [62,
#   62,
#   62,
#   62,
#   62,
#   62,
#   62,
#   62,
#   62,
#   62,
#   64,
#   64,
#   120,
#   62,
#   62,
#   64,
#   71,
#   62],
#  'Lawyers in Love ': [240],
#  'Privilege ': [291],
#  'Memoir ': [438],
#  'Port Fare ': [520],
#  'One Night with Sole Regret ': [103],
#  'The Witch Hunter Saga ': [302],
#  'Bar Code ': [250],
#  'Fearless ': [320],
#  'Highland Guard ': [405],
#  'The Captive ': [212, 234, 270],
#  'Nigel Strangeways ': [260],
#  'Marvel 1602 ': [248],
#  'Runemarks ': [528],
#  'La Comédie Humaine ': [285, 146, 57, 272, 339],
#  'Until ': [238],
#  'Less Than Three ': [48, 50, 35],
#  'Tantalize ': [310],
#  'Grant County ': [422, 404, 384, 549],
#  'Johnny Maxwell ': [210],
#  'Ramona Quimby ': [160, 150, 160],
#  'Dragonfire ': [334, 392, 494],
#  'The Twilight Saga: The Official Illustrated Movie Companion ': [144, 144],
#  'Seven Wonders ': [348],
#  'Father Brown ': [232],
#  'Souls  ': [336],
#  'A Scots Quair ': [272],
#  'Chocolate Lovers’ Club ': [352, 352],
#  'Dear America': [219, 204, 192, 188],
#  "Thieves' World ": [308],
#  'The League of Extraordinary Gentlemen ': [192],
#  'The Bridei Chronicles ': [496, 561],
#  'Love at Stake ': [373, 371, 370, 350, 369],
#  'Swamp Thing 1982 Collected Editions ': [173],
#  'Rambo: First Blood ': [320],
#  'Röde Orm ': [477],
#  'Miss Marple ': [351, 288, 224],
#  'Thompson Sisters ': [369, 482],
#  'Winning ': [384],
#  'Holland Family Saga ': [435],
#  'Betsy-Tacy ': [144, 320, 352, 704, 192],
#  'Heather Wells ': [280, 344],
#  'Genius ': [448],
#  'Avatar: The Last Airbender Comics ': [76, 76, 96, 76, 76, 76],
#  'Henry II and Eleanor of Aquitaine ': [544],
#  'Turtle in Paradise': [177],
#  'The Storm ': [401],
#  'Timeless Love ': [528],
#  'Grail Quest ': [412, 416, 400],
#  'Witch ': [292, 276],
#  'The Fallen ': [517, 305, 352, 352, 352, 541],
#  'Dreamhouse Kings ': [295],
#  'Darkest London ': [372, 384],
#  "Night's Dawn ": [1273, 1174, 608, 572, 592],
#  'King Dork ': [344],
#  'Marriage to a Billionaire ': [401, 328],
#  'An Unfortunate Fairy Tale ': [297, nan],
#  'Consumed ': [nan],
#  'Only Vallerands ': [390],
#  'Hourglass ': [390],
#  'Genesis of Shannara ': [379, 371, 402],
#  'Long Price Quartet ': [331, 366],
#  'The Sisters Grimm ': [306, 274, 352],
#  'Mating Heat ': [179, 150],
#  'Rock Chick ': [484, 530],
#  'Forever ': [282, 176, 256, 239],
#  "Roald Dahl's Tales of the Unexpected ": [471],
#  'One Night ': [480, 145],
#  'Chesapeake Bay Saga ': [330, 357, 330],
#  'The Faerie Queene Books': [1248],
#  'Faery Rebels ': [320],
#  'The Mephisto Covenant ': [438],
#  ...}

# %%
dictionary
# Out:
# {'The Hunger Games ': [0,
#   185,
#   222,
#   321,
#   742,
#   927,
#   964,
#   1063,
#   1996,
#   2181,
#   2218,
#   2317,
#   2906,
#   2914,
#   3014,
#   3199,
#   3236,
#   3291,
#   3476,
#   3513,
#   3613,
#   5179,
#   5364,
#   5401,
#   5501,
#   6119,
#   6304,
#   6341,
#   6441,
#   7166,
#   7351,
#   7388,
#   7488],
#  'Harry Potter ': [1,
#   31,
#   70,
#   91,
#   102,
#   105,
#   125,
#   406,
#   743,
#   773,
#   812,
#   833,
#   844,
#   847,
#   867,
#   1148,
#   1997,
#   2027,
#   2066,
#   2087,
#   2098,
#   2101,
#   2121,
#   2402,
#   2907,
#   2915,
#   2945,
#   2984,
#   3005,
#   3015,
#   3045,
#   3084,
#   3105,
#   3116,
#   3119,
#   3139,
#   3292,
#   3322,
#   3361,
#   3382,
#   3393,
#   3396,
#   3416,
#   3698,
#   4601,
#   4867,
#   5180,
#   5210,
#   5249,
#   5270,
#   5281,
#   5284,
#   5304,
#   5586,
#   6120,
#   6150,
#   6189,
#   6210,
#   6221,
#   6224,
#   6244,
#   6526,
#   7167,
#   7197,
#   7236,
#   7257,
#   7268,
#   7271,
#   7291,
#   7573,
#   8476,
#   8743,
#   9408,
#   16904],
#  'To Kill a Mockingbird': [2,
#   744,
#   1998,
#   2908,
#   2916,
#   3016,
#   3293,
#   5181,
#   6121,
#   7168,
#   24998],
#  'The Twilight Saga ': [4,
#   475,
#   746,
#   1217,
#   1717,
#   1834,
#   1838,
#   1919,
#   2000,
#   2471,
#   2910,
#   2918,
#   3018,
#   3295,
#   3766,
#   4265,
#   4382,
#   4386,
#   4467,
#   5183,
#   5654,
#   6123,
#   6594,
#   7093,
#   7170,
#   7641,
#   8140,
#   8257,
#   8261,
#   8342,
#   21289],
#  'The Chronicles of Narnia Publication Order ': [7,
#   139,
#   461,
#   486,
#   549,
#   599,
#   615,
#   749,
#   881,
#   1203,
#   1228,
#   1291,
#   1341,
#   1357,
#   2003,
#   2135,
#   2457,
#   2482,
#   2545,
#   2595,
#   2611,
#   2913,
#   2921,
#   3021,
#   3153,
#   3298,
#   3430,
#   3753,
#   3777,
#   3839,
#   3889,
#   3905,
#   5186,
#   5318,
#   5641,
#   5665,
#   5727,
#   5777,
#   5793,
#   6126,
#   6258,
#   6581,
#   6605,
#   6667,
#   6717,
#   6733,
#   7173,
#   7305,
#   7628,
#   7652,
#   7714,
#   7764,
#   7780],
#  'The Lord of the Rings ': [8,
#   92,
#   166,
#   332,
#   539,
#   604,
#   750,
#   834,
#   908,
#   1074,
#   1281,
#   1346,
#   2004,
#   2088,
#   2162,
#   2328,
#   2535,
#   2600,
#   2922,
#   3006,
#   3022,
#   3106,
#   3180,
#   3299,
#   3383,
#   3457,
#   3624,
#   3894,
#   5187,
#   5271,
#   5345,
#   5512,
#   5782,
#   6127,
#   6211,
#   6285,
#   6452,
#   6722,
#   7174,
#   7258,
#   7332,
#   7499,
#   7769],
#  "The Hitchhiker's Guide to the Galaxy ": [11,
#   155,
#   753,
#   897,
#   1531,
#   1747,
#   2007,
#   2151,
#   2785,
#   2925,
#   3025,
#   3169,
#   3302,
#   3446,
#   4079,
#   4295,
#   4959,
#   5190,
#   5334,
#   5967,
#   6130,
#   6274,
#   6907,
#   7123,
#   7177,
#   7321,
#   7954,
#   8170,
#   8833,
#   9216,
#   23304],
#  'Robert Langdon ': [14,
#   451,
#   515,
#   661,
#   756,
#   1193,
#   1257,
#   1403,
#   2010,
#   2447,
#   2511,
#   2657,
#   2928,
#   3028,
#   3305,
#   3743,
#   3806,
#   3951,
#   5193,
#   5631,
#   5694,
#   5839,
#   6133,
#   6571,
#   6634,
#   6779,
#   7180,
#   7618,
#   7681,
#   7826,
#   9274],
#  "Alice's Adventures in Wonderland ": [17,
#   759,
#   2013,
#   2931,
#   3031,
#   3308,
#   5130,
#   5196,
#   6136,
#   7183,
#   9003],
#  'Divergent ': [21,
#   151,
#   333,
#   763,
#   893,
#   1075,
#   2017,
#   2147,
#   2329,
#   2935,
#   3035,
#   3165,
#   3312,
#   3442,
#   3625,
#   4614,
#   4998,
#   5200,
#   5330,
#   5513,
#   6140,
#   6270,
#   6453,
#   7187,
#   7317,
#   7500,
#   8489,
#   8871,
#   9483,
#   11845,
#   14539]}

# %%
for i in range(len(dictionary)):
    dictionary.get(i)
